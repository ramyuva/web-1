# %%
from bs4 import BeautifulSoup
import requests
import re


url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []

# Store each item into dictionary (data), then put those into a list (imdb)
for index in range(0, len(movies)):
    # Seperate movie into: 'place', 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

# %%
for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino
# 3 - The Godfather: Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro
# 4 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman
# 9 - Il buono, il brutto, il cattivo (1966) - Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach
# 1 -  The Lord of the Rings: The Fellowship of the Ring (2001) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen
# 11 - Fight Club (1999) - Starring: David Fincher (dir.), Brad Pitt, Edward Norton
# 12 - Forrest Gump (1994) - Starring: Robert Zemeckis (dir.), Tom Hanks, Robin Wright
# 13 - Inception (2010) - Starring: Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt
# 14 - The Lord of the Rings: The Two Towers (2002) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen
# 15 - Star Wars: Episode V - The Empire Strikes Back (1980) - Starring: Irvin Kershner (dir.), Mark Hamill, Harrison Ford
# 16 - The Matrix (1999) - Starring: Lana Wachowski (dir.), Keanu Reeves, Laurence Fishburne
# 17 - Goodfellas (1990) - Starring: Martin Scorsese (dir.), Robert De Niro, Ray Liotta
# 18 - One Flew Over the Cuckoo's Nest (1975) - Starring: Milos Forman (dir.), Jack Nicholson, Louise Fletcher
# 19 - Shichinin no samurai (1954) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Takashi Shimura
# 20 - Se7en (1995) - Starring: David Fincher (dir.), Morgan Freeman, Brad Pitt
# 21 - La vita è bella (1997) - Starring: Roberto Benigni (dir.), Roberto Benigni, Nicoletta Braschi
# 22 - Cidade de Deus (2002) - Starring: Fernando Meirelles (dir.), Alexandre Rodrigues, Leandro Firmino
# 23 - The Silence of the Lambs (1991) - Starring: Jonathan Demme (dir.), Jodie Foster, Anthony Hopkins
# 24 - It's a Wonderful Life (1946) - Starring: Frank Capra (dir.), James Stewart, Donna Reed
# 25 - Star Wars (1977) - Starring: George Lucas (dir.), Mark Hamill, Harrison Ford
# 26 - Saving Private Ryan (1998) - Starring: Steven Spielberg (dir.), Tom Hanks, Matt Damon
# 27 - The Green Mile (1999) - Starring: Frank Darabont (dir.), Tom Hanks, Michael Clarke Duncan
# 28 - Sen to Chihiro no kamikakushi (2001) - Starring: Hayao Miyazaki (dir.), Daveigh Chase, Suzanne Pleshette
# 29 - Interstellar (2014) - Starring: Christopher Nolan (dir.), Matthew McConaughey, Anne Hathaway
# 30 - Gisaengchung (2019) - Starring: Bong Joon Ho (dir.), Kang-ho Song, Lee Sun-kyun
# 31 - Léon (1994) - Starring: Luc Besson (dir.), Jean Reno, Gary Oldman
# 32 - Seppuku (1962) - Starring: Masaki Kobayashi (dir.), Tatsuya Nakadai, Akira Ishihama
# 33 - The Usual Suspects (1995) - Starring: Bryan Singer (dir.), Kevin Spacey, Gabriel Byrne
# 34 - The Lion King (1994) - Starring: Roger Allers (dir.), Matthew Broderick, Jeremy Irons
# 35 - The Pianist (2002) - Starring: Roman Polanski (dir.), Adrien Brody, Thomas Kretschmann
# 36 - Back to the Future (1985) - Starring: Robert Zemeckis (dir.), Michael J. Fox, Christopher Lloyd
# 37 - Terminator 2: Judgment Day (1991) - Starring: James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton
# 38 - American History X (1998) - Starring: Tony Kaye (dir.), Edward Norton, Edward Furlong
# 39 - Modern Times (1936) - Starring: Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard
# 40 - Psycho (1960) - Starring: Alfred Hitchcock (dir.), Anthony Perkins, Janet Leigh
# 41 - Gladiator (2000) - Starring: Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix
# 42 - City Lights (1931) - Starring: Charles Chaplin (dir.), Charles Chaplin, Virginia Cherrill
# 43 - The Departed (2006) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Matt Damon
# 44 - The Intouchables (2011) - Starring: Olivier Nakache (dir.), François Cluzet, Omar Sy
# 45 - Whiplash (2014) - Starring: Damien Chazelle (dir.), Miles Teller, J.K. Simmons
# 46 - Hotaru no haka (1988) - Starring: Isao Takahata (dir.), Tsutomu Tatsumi, Ayano Shiraishi
# 47 - The Prestige (2006) - Starring: Christopher Nolan (dir.), Christian Bale, Hugh Jackman
# 48 - Once Upon a Time in the West (1968) - Starring: Sergio Leone (dir.), Henry Fonda, Charles Bronson
# 49 - Casablanca (1942) - Starring: Michael Curtiz (dir.), Humphrey Bogart, Ingrid Bergman
# 50 - Nuovo Cinema Paradiso (1988) - Starring: Giuseppe Tornatore (dir.), Philippe Noiret, Enzo Cannavale
# 51 - Rear Window (1954) - Starring: Alfred Hitchcock (dir.), James Stewart, Grace Kelly
# 52 - Alien (1979) - Starring: Ridley Scott (dir.), Sigourney Weaver, Tom Skerritt
# 53 - Apocalypse Now (1979) - Starring: Francis Ford Coppola (dir.), Martin Sheen, Marlon Brando
# 54 - Memento (2000) - Starring: Christopher Nolan (dir.), Guy Pearce, Carrie-Anne Moss
# 55 - The Great Dictator (1940) - Starring: Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard
# 56 - Raiders of the Lost Ark (1981) - Starring: Steven Spielberg (dir.), Harrison Ford, Karen Allen
# 57 - Hamilton (2020) - Starring: Thomas Kail (dir.), Lin-Manuel Miranda, Phillipa Soo
# 58 - Django Unchained (2012) - Starring: Quentin Tarantino (dir.), Jamie Foxx, Christoph Waltz
# 59 - The Lives of Others (2006) - Starring: Florian Henckel von Donnersmarck (dir.), Ulrich Mühe, Martina Gedeck
# 60 - Paths of Glory (1957) - Starring: Stanley Kubrick (dir.), Kirk Douglas, Ralph Meeker
# 61 - Joker (2019) - Starring: Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro
# 62 - WALL·E (2008) - Starring: Andrew Stanton (dir.), Ben Burtt, Elissa Knight
# 63 - The Shining (1980) - Starring: Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall
# 64 - Avengers: Infinity War (2018) - Starring: Anthony Russo (dir.), Robert Downey Jr., Chris Hemsworth
# 65 - Sunset Blvd (1950) - Starring: Billy Wilder (dir.), William Holden, Gloria Swanson
# 66 - Witness for the Prosecution (1957) - Starring: Billy Wilder (dir.), Tyrone Power, Marlene Dietrich
# 67 - Oldeuboi (2003) - Starring: Chan-wook Park (dir.), Choi Min-sik, Yoo Ji-Tae
# 68 - Mononoke-hime (1997) - Starring: Hayao Miyazaki (dir.), Yôji Matsuda, Yuriko Ishida
# 69 - Spider-Man: Into the Spider-Verse (2018) - Starring: Bob Persichetti (dir.), Shameik Moore, Jake Johnson
# 70 - Dr Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964) - Starring: Stanley Kubrick (dir.), Peter Sellers, George C. Scott
# 71 - The Dark Knight Rises (2012) - Starring: Christopher Nolan (dir.), Christian Bale, Tom Hardy
# 72 - Once Upon a Time in America (1984) - Starring: Sergio Leone (dir.), Robert De Niro, James Woods
# 73 - Kimi no na wa (2016) - Starring: Makoto Shinkai (dir.), Ryûnosuke Kamiki, Mone Kamishiraishi
# 74 - Aliens (1986) - Starring: James Cameron (dir.), Sigourney Weaver, Michael Biehn
# 75 - Coco (2017) - Starring: Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal
# 76 - Avengers: Endgame (2019) - Starring: Anthony Russo (dir.), Robert Downey Jr., Chris Evans
# 77 - American Beauty (1999) - Starring: Sam Mendes (dir.), Kevin Spacey, Annette Bening
# 78 - Braveheart (1995) - Starring: Mel Gibson (dir.), Mel Gibson, Sophie Marceau
# 79 - Capharnaüm (2018) - Starring: Nadine Labaki (dir.), Zain Al Rafeea, Yordanos Shiferaw
# 80 - Das Boot (1981) - Starring: Wolfgang Petersen (dir.), Jürgen Prochnow, Herbert Grönemeyer
# 81 - 3 Idiots (2009) - Starring: Rajkumar Hirani (dir.), Aamir Khan, Madhavan
# 82 - Toy Story (1995) - Starring: John Lasseter (dir.), Tom Hanks, Tim Allen
# 83 - Tengoku to jigoku (1963) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Yutaka Sada
# 84 - Amadeus (1984) - Starring: Milos Forman (dir.), F. Murray Abraham, Tom Hulce
# 85 - Inglourious Basterds (2009) - Starring: Quentin Tarantino (dir.), Brad Pitt, Diane Kruger
# 86 - Star Wars: Episode VI - Return of the Jedi (1983) - Starring: Richard Marquand (dir.), Mark Hamill, Harrison Ford
# 87 - Good Will Hunting (1997) - Starring: Gus Van Sant (dir.), Robin Williams, Matt Damon
# 88 - Taare Zameen Par (2007) - Starring: Aamir Khan (dir.), Darsheel Safary, Aamir Khan
# 89 - Reservoir Dogs (1992) - Starring: Quentin Tarantino (dir.), Harvey Keitel, Tim Roth
# 90 - 2001: A Space Odyssey (1968) - Starring: Stanley Kubrick (dir.), Keir Dullea, Gary Lockwood
# 91 - Requiem for a Dream (2000) - Starring: Darren Aronofsky (dir.), Ellen Burstyn, Jared Leto
# 92 - Vertigo (1958) - Starring: Alfred Hitchcock (dir.), James Stewart, Kim Novak
# 93 - M - Eine Stadt sucht einen Mörder (1931) - Starring: Fritz Lang (dir.), Peter Lorre, Ellen Widmann
# 94 - Jagten (2012) - Starring: Thomas Vinterberg (dir.), Mads Mikkelsen, Thomas Bo Larsen
# 95 - Eternal Sunshine of the Spotless Mind (2004) - Starring: Michel Gondry (dir.), Jim Carrey, Kate Winslet
# 96 - Citizen Kane (1941) - Starring: Orson Welles (dir.), Orson Welles, Joseph Cotten
# 97 - Dangal (2016) - Starring: Nitesh Tiwari (dir.), Aamir Khan, Sakshi Tanwar
# 98 - Full Metal Jacket (1987) - Starring: Stanley Kubrick (dir.), Matthew Modine, R. Lee Ermey
# 99 - Ladri di biciclette (1948) - Starring: Vittorio De Sica (dir.), Lamberto Maggiorani, Enzo Staiola
# 10 -  Singin' in the Rain (1952) - Starring: Stanley Donen (dir.), Gene Kelly, Donald O'Connor
# 101 - The Kid (1921) - Starring: Charles Chaplin (dir.), Charles Chaplin, Edna Purviance
# 102 - Snatch (2000) - Starring: Guy Ritchie (dir.), Jason Statham, Brad Pitt
# 103 - North by Northwest (1959) - Starring: Alfred Hitchcock (dir.), Cary Grant, Eva Marie Saint
# 104 - A Clockwork Orange (1971) - Starring: Stanley Kubrick (dir.), Malcolm McDowell, Patrick Magee
# 105 - Scarface (1983) - Starring: Brian De Palma (dir.), Al Pacino, Michelle Pfeiffer
# 106 - 1917 (2019) - Starring: Sam Mendes (dir.), Dean-Charles Chapman, George MacKay
# 107 - Idi i smotri (1985) - Starring: Elem Klimov (dir.), Aleksey Kravchenko, Olga Mironova
# 108 - Ikiru (1952) - Starring: Akira Kurosawa (dir.), Takashi Shimura, Nobuo Kaneko
# 109 - Taxi Driver (1976) - Starring: Martin Scorsese (dir.), Robert De Niro, Jodie Foster
# 110 - Toy Story 3 (2010) - Starring: Lee Unkrich (dir.), Tom Hanks, Tim Allen
# 111 - Lawrence of Arabia (1962) - Starring: David Lean (dir.), Peter O'Toole, Alec Guinness
# 112 - Jodaeiye Nader az Simin (2011) - Starring: Asghar Farhadi (dir.), Payman Maadi, Leila Hatami
# 113 - Amélie (2001) - Starring: Jean-Pierre Jeunet (dir.), Audrey Tautou, Mathieu Kassovitz
# 114 - Incendies (2010) - Starring: Denis Villeneuve (dir.), Lubna Azabal, Mélissa Désormeaux-Poulin
# 115 - The Sting (1973) - Starring: George Roy Hill (dir.), Paul Newman, Robert Redford
# 116 - Metropolis (1927) - Starring: Fritz Lang (dir.), Brigitte Helm, Alfred Abel
# 117 - Per qualche dollaro in più (1965) - Starring: Sergio Leone (dir.), Clint Eastwood, Lee Van Cleef
# 118 - The Apartment (1960) - Starring: Billy Wilder (dir.), Jack Lemmon, Shirley MacLaine
# 119 - Double Indemnity (1944) - Starring: Billy Wilder (dir.), Fred MacMurray, Barbara Stanwyck
# 120 - To Kill a Mockingbird (1962) - Starring: Robert Mulligan (dir.), Gregory Peck, John Megna
# 121 - Up (2009) - Starring: Pete Docter (dir.), Edward Asner, Jordan Nagai
# 122 - Indiana Jones and the Last Crusade (1989) - Starring: Steven Spielberg (dir.), Harrison Ford, Sean Connery
# 123 - Heat (1995) - Starring: Michael Mann (dir.), Al Pacino, Robert De Niro
# 124 - LA Confidential (1997) - Starring: Curtis Hanson (dir.), Kevin Spacey, Russell Crowe
# 125 - Die Hard (1988) - Starring: John McTiernan (dir.), Bruce Willis, Alan Rickman
# 126 - Green Book (2018) - Starring: Peter Farrelly (dir.), Viggo Mortensen, Mahershala Ali
# 127 - Monty Python and the Holy Grail (1975) - Starring: Terry Gilliam (dir.), Graham Chapman, John Cleese
# 128 - Batman Begins (2005) - Starring: Christopher Nolan (dir.), Christian Bale, Michael Caine
# 129 - Yôjinbô (1961) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Eijirô Tôno
# 130 - Rashômon (1950) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Machiko Kyô
# 131 - Der Untergang (2004) - Starring: Oliver Hirschbiegel (dir.), Bruno Ganz, Alexandra Maria Lara
# 132 - Bacheha-Ye aseman (1997) - Starring: Majid Majidi (dir.), Mohammad Amir Naji, Amir Farrokh Hashemian
# 133 - Unforgiven (1992) - Starring: Clint Eastwood (dir.), Clint Eastwood, Gene Hackman
# 134 - Ran (1985) - Starring: Akira Kurosawa (dir.), Tatsuya Nakadai, Akira Terao
# 135 - Some Like It Hot (1959) - Starring: Billy Wilder (dir.), Marilyn Monroe, Tony Curtis
# 136 - Hauru no ugoku shiro (2004) - Starring: Hayao Miyazaki (dir.), Chieko Baishô, Takuya Kimura
# 137 - All About Eve (1950) - Starring: Joseph L. Mankiewicz (dir.), Bette Davis, Anne Baxter
# 138 - Casino (1995) - Starring: Martin Scorsese (dir.), Robert De Niro, Sharon Stone
# 139 - A Beautiful Mind (2001) - Starring: Ron Howard (dir.), Russell Crowe, Ed Harris
# 140 - The Great Escape (1963) - Starring: John Sturges (dir.), Steve McQueen, James Garner
# 141 - The Wolf of Wall Street (2013) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Jonah Hill
# 142 - Pan's Labyrinth (2006) - Starring: Guillermo del Toro (dir.), Ivana Baquero, Ariadna Gil
# 143 - El secreto de sus ojos (2009) - Starring: Juan José Campanella (dir.), Ricardo Darín, Soledad Villamil
# 144 - There Will Be Blood (2007) - Starring: Paul Thomas Anderson (dir.), Daniel Day-Lewis, Paul Dano
# 145 - Lock, Stock and Two Smoking Barrels (1998) - Starring: Guy Ritchie (dir.), Jason Flemyng, Dexter Fletcher
# 146 - Tonari no Totoro (1988) - Starring: Hayao Miyazaki (dir.), Hitoshi Takagi, Noriko Hidaka
# 147 - Judgment at Nuremberg (1961) - Starring: Stanley Kramer (dir.), Spencer Tracy, Burt Lancaster
# 148 - Raging Bull (1980) - Starring: Martin Scorsese (dir.), Robert De Niro, Cathy Moriarty
# 149 - The Treasure of the Sierra Madre (1948) - Starring: John Huston (dir.), Humphrey Bogart, Walter Huston
# 150 - Dial M for Murder (1954) - Starring: Alfred Hitchcock (dir.), Ray Milland, Grace Kelly
# 151 - Three Billboards Outside Ebbing, Missouri (2017) - Starring: Martin McDonagh (dir.), Frances McDormand, Woody Harrelson
# 152 - Shutter Island (2010) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Emily Mortimer
# 153 - Chinatown (1974) - Starring: Roman Polanski (dir.), Jack Nicholson, Faye Dunaway
# 154 - The Gold Rush (1925) - Starring: Charles Chaplin (dir.), Charles Chaplin, Mack Swain
# 155 - Babam ve Oglum (2005) - Starring: Veysel Aslan (dir.), Eser Sariyar, Çetin Tekindor
# 156 - No Country for Old Men (2007) - Starring: Ethan Coen (dir.), Tommy Lee Jones, Javier Bardem
# 157 - V for Vendetta (2005) - Starring: James McTeigue (dir.), Hugo Weaving, Natalie Portman
# 158 - Inside Out (2015) - Starring: Pete Docter (dir.), Amy Poehler, Bill Hader
# 159 - Det sjunde inseglet (1957) - Starring: Ingmar Bergman (dir.), Max von Sydow, Gunnar Björnstrand
# 160 - The Elephant Man (1980) - Starring: David Lynch (dir.), Anthony Hopkins, John Hurt
# 161 - The Thing (1982) - Starring: John Carpenter (dir.), Kurt Russell, Wilford Brimley
# 162 - Warrior (2011) - Starring: Gavin O'Connor (dir.), Tom Hardy, Nick Nolte
# 163 - The Sixth Sense (1999) - Starring: M. Night Shyamalan (dir.), Bruce Willis, Haley Joel Osment
# 164 - Trainspotting (1996) - Starring: Danny Boyle (dir.), Ewan McGregor, Ewen Bremner
# 165 - Jurassic Park (1993) - Starring: Steven Spielberg (dir.), Sam Neill, Laura Dern
# 166 - Klaus (2019) - Starring: Sergio Pablos (dir.), Jason Schwartzman, J.K. Simmons
# 167 - The Truman Show (1998) - Starring: Peter Weir (dir.), Jim Carrey, Ed Harris
# 168 - Gone with the Wind (1939) - Starring: Victor Fleming (dir.), Clark Gable, Vivien Leigh
# 169 - Finding Nemo (2003) - Starring: Andrew Stanton (dir.), Albert Brooks, Ellen DeGeneres
# 170 - Smultronstället (1957) - Starring: Ingmar Bergman (dir.), Victor Sjöström, Bibi Andersson
# 171 - Blade Runner (1982) - Starring: Ridley Scott (dir.), Harrison Ford, Rutger Hauer
# 172 - Stalker (1979) - Starring: Andrei Tarkovsky (dir.), Alisa Freyndlikh, Aleksandr Kaydanovskiy
# 173 - Kill Bill: Vol 1 (2003) - Starring: Quentin Tarantino (dir.), Uma Thurman, David Carradine
# 174 - Salinui chueok (2003) - Starring: Bong Joon Ho (dir.), Kang-ho Song, Kim Sang-kyung
# 175 - Fargo (1996) - Starring: Joel Coen (dir.), William H. Macy, Frances McDormand
# 176 - The Bridge on the River Kwai (1957) - Starring: David Lean (dir.), William Holden, Alec Guinness
# 177 - Room (2015) - Starring: Lenny Abrahamson (dir.), Brie Larson, Jacob Tremblay
# 178 - Relatos salvajes (2014) - Starring: Damián Szifron (dir.), Darío Grandinetti, María Marull
# 179 - Gran Torino (2008) - Starring: Clint Eastwood (dir.), Clint Eastwood, Bee Vang
# 180 - The Third Man (1949) - Starring: Carol Reed (dir.), Orson Welles, Joseph Cotten
# 181 - Tôkyô monogatari (1953) - Starring: Yasujirô Ozu (dir.), Chishû Ryû, Chieko Higashiyama
# 182 - On the Waterfront (1954) - Starring: Elia Kazan (dir.), Marlon Brando, Karl Malden
# 183 - The Deer Hunter (1978) - Starring: Michael Cimino (dir.), Robert De Niro, Christopher Walken
# 184 - In the Name of the Father (1993) - Starring: Jim Sheridan (dir.), Daniel Day-Lewis, Pete Postlethwaite
# 185 - Mary and Max (2009) - Starring: Adam Elliot (dir.), Toni Collette, Philip Seymour Hoffman
# 186 - The Grand Budapest Hotel (2014) - Starring: Wes Anderson (dir.), Ralph Fiennes, F. Murray Abraham
# 187 - Gone Girl (2014) - Starring: David Fincher (dir.), Ben Affleck, Rosamund Pike
# 188 - Before Sunrise (1995) - Starring: Richard Linklater (dir.), Ethan Hawke, Julie Delpy
# 189 - Anand (1971) - Starring: Hrishikesh Mukherjee (dir.), Rajesh Khanna, Amitabh Bachchan
# 190 - Catch Me If You Can (2002) - Starring: Steven Spielberg (dir.), Leonardo DiCaprio, Tom Hanks
# 191 - Hacksaw Ridge (2016) - Starring: Mel Gibson (dir.), Andrew Garfield, Sam Worthington
# 192 - Persona (1966) - Starring: Ingmar Bergman (dir.), Bibi Andersson, Liv Ullmann
# 193 - Prisoners (2013) - Starring: Denis Villeneuve (dir.), Hugh Jackman, Jake Gyllenhaal
# 194 - Andhadhun (2018) - Starring: Sriram Raghavan (dir.), Ayushmann Khurrana, Tabu
# 195 - Höstsonaten (1978) - Starring: Ingmar Bergman (dir.), Ingrid Bergman, Liv Ullmann
# 196 - The Big Lebowski (1998) - Starring: Joel Coen (dir.), Jeff Bridges, John Goodman
# 197 - Sherlock Jr (1924) - Starring: Buster Keaton (dir.), Buster Keaton, Kathryn McGuire
# 198 - To Be or Not to Be (1942) - Starring: Ernst Lubitsch (dir.), Carole Lombard, Jack Benny
# 199 - The General (1926) - Starring: Clyde Bruckman (dir.), Buster Keaton, Marion Mack
# 200 - How to Train Your Dragon (2010) - Starring: Dean DeBlois (dir.), Jay Baruchel, Gerard Butler
# 201 - Ford v Ferrari (2019) - Starring: James Mangold (dir.), Matt Damon, Christian Bale
# 202 - Barry Lyndon (1975) - Starring: Stanley Kubrick (dir.), Ryan O'Neal, Marisa Berenson
# 203 - 12 Years a Slave (2013) - Starring: Steve McQueen (dir.), Chiwetel Ejiofor, Michael Kenneth Williams
# 204 - Eskiya (1996) - Starring: Yavuz Turgul (dir.), Sener Sen, Ugur Yücel
# 205 - Mr Smith Goes to Washington (1939) - Starring: Frank Capra (dir.), James Stewart, Jean Arthur
# 206 - Soul (2020) - Starring: Pete Docter (dir.), Jamie Foxx, Tina Fey
# 207 - Mad Max: Fury Road (2015) - Starring: George Miller (dir.), Tom Hardy, Charlize Theron
# 208 - Million Dollar Baby (2004) - Starring: Clint Eastwood (dir.), Hilary Swank, Clint Eastwood
# 209 - Dead Poets Society (1989) - Starring: Peter Weir (dir.), Robin Williams, Robert Sean Leonard
# 210 - Network (1976) - Starring: Sidney Lumet (dir.), Faye Dunaway, William Holden
# 211 - Stand by Me (1986) - Starring: Rob Reiner (dir.), Wil Wheaton, River Phoenix
# 212 - Harry Potter and the Deathly Hallows: Part 2 (2011) - Starring: David Yates (dir.), Daniel Radcliffe, Emma Watson
# 213 - Ben-Hur (1959) - Starring: William Wyler (dir.), Charlton Heston, Jack Hawkins
# 214 - Hachi: A Dog's Tale (2009) - Starring: Lasse Hallström (dir.), Richard Gere, Joan Allen
# 215 - Cool Hand Luke (1967) - Starring: Stuart Rosenberg (dir.), Paul Newman, George Kennedy
# 216 - Ah-ga-ssi (2016) - Starring: Chan-wook Park (dir.), Kim Min-hee, Jung-woo Ha
# 217 - Platoon (1986) - Starring: Oliver Stone (dir.), Charlie Sheen, Tom Berenger
# 218 - Logan (2017) - Starring: James Mangold (dir.), Hugh Jackman, Patrick Stewart
# 219 - Into the Wild (2007) - Starring: Sean Penn (dir.), Emile Hirsch, Vince Vaughn
# 220 - Le salaire de la peur (1953) - Starring: Henri-Georges Clouzot (dir.), Yves Montand, Charles Vanel
# 221 - Rush (2013) - Starring: Ron Howard (dir.), Daniel Brühl, Chris Hemsworth
# 222 - Life of Brian (1979) - Starring: Terry Jones (dir.), Graham Chapman, John Cleese
# 223 - La haine (1995) - Starring: Mathieu Kassovitz (dir.), Vincent Cassel, Hubert Koundé
# 224 - La passion de Jeanne d'Arc (1928) - Starring: Carl Theodor Dreyer (dir.), Maria Falconetti, Eugene Silvain
# 225 - Les quatre cents coups (1959) - Starring: François Truffaut (dir.), Jean-Pierre Léaud, Albert Rémy
# 226 - Spotlight (2015) - Starring: Tom McCarthy (dir.), Mark Ruffalo, Michael Keaton
# 227 - Hotel Rwanda (2004) - Starring: Terry George (dir.), Don Cheadle, Sophie Okonedo
# 228 - Dom za vesanje (1988) - Starring: Emir Kusturica (dir.), Davor Dujmovic, Bora Todorovic
# 229 - Amores perros (2000) - Starring: Alejandro G. Iñárritu (dir.), Emilio Echevarría, Gael García Bernal
# 230 - Gangs of Wasseypur (2012) - Starring: Anurag Kashyap (dir.), Manoj Bajpayee, Richa Chadha
# 231 - Rocky (1976) - Starring: John G. Avildsen (dir.), Sylvester Stallone, Talia Shire
# 232 - Andrei Rublev (1966) - Starring: Andrei Tarkovsky (dir.), Anatoliy Solonitsyn, Ivan Lapikov
# 233 - Monsters, Inc (2001) - Starring: Pete Docter (dir.), Billy Crystal, John Goodman
# 234 - Kaze no tani no Naushika (1984) - Starring: Hayao Miyazaki (dir.), Sumi Shimamoto, Mahito Tsujimura
# 235 - Rebecca (1940) - Starring: Alfred Hitchcock (dir.), Laurence Olivier, Joan Fontaine
# 236 - Du rififi chez les hommes (1955) - Starring: Jules Dassin (dir.), Jean Servais, Carl Möhner
# 237 - Rang De Basanti (2006) - Starring: Rakeysh Omprakash Mehra (dir.), Aamir Khan, Soha Ali Khan
# 238 - Before Sunset (2004) - Starring: Richard Linklater (dir.), Ethan Hawke, Julie Delpy
# 239 - Fa yeung nin wah (2000) - Starring: Kar-Wai Wong (dir.), Tony Chiu-Wai Leung, Maggie Cheung
# 240 - Paris, Texas (1984) - Starring: Wim Wenders (dir.), Harry Dean Stanton, Nastassja Kinski
# 241 - Portrait de la jeune fille en feu (2019) - Starring: Céline Sciamma (dir.), Noémie Merlant, Adèle Haenel
# 242 - It Happened One Night (1934) - Starring: Frank Capra (dir.), Clark Gable, Claudette Colbert
# 243 - Contratiempo (2016) - Starring: Oriol Paulo (dir.), Mario Casas, Ana Wagener
# 244 - Drishyam (2015) - Starring: Nishikant Kamat (dir.), Ajay Devgn, Shriya Saran
# 245 - Koe no katachi (2016) - Starring: Naoko Yamada (dir.), Miyu Irino, Saori Hayami
# 246 - Mandariinid (2013) - Starring: Zaza Urushadze (dir.), Lembit Ulfsak, Elmo Nüganen
# 247 - The Help (2011) - Starring: Tate Taylor (dir.), Emma Stone, Viola Davis
# 248 - Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni (1997) - Starring: Hideaki Anno (dir.), Megumi Ogata, Megumi Hayashibara
# 249 - La battaglia di Algeri (1966) - Starring: Gillo Pontecorvo (dir.), Brahim Hadjadj, Jean Martin
# 250 - The Princess Bride (1987) - Starring: Rob Reiner (dir.), Cary Elwes, Mandy Patinkin

# %%
imdb
# Out:
# [{'movie_title': 'The Shawshank Redemption',
#   'year': '1994',
#   'place': '1',
#   'star_cast': 'Frank Darabont (dir.), Tim Robbins, Morgan Freeman',
#   'rating': '9.22338655927294',
#   'vote': None,
#   'link': '/title/tt0111161/'},
#  {'movie_title': 'The Godfather',
#   'year': '1972',
#   'place': '2',
#   'star_cast': 'Francis Ford Coppola (dir.), Marlon Brando, Al Pacino',
#   'rating': '9.148134749783218',
#   'vote': None,
#   'link': '/title/tt0068646/'},
#  {'movie_title': 'The Godfather: Part II',
#   'year': '1974',
#   'place': '3',
#   'star_cast': 'Francis Ford Coppola (dir.), Al Pacino, Robert De Niro',
#   'rating': '8.98035242665388',
#   'vote': None,
#   'link': '/title/tt0071562/'},
#  {'movie_title': 'The Dark Knight',
#   'year': '2008',
#   'place': '4',
#   'star_cast': 'Christopher Nolan (dir.), Christian Bale, Heath Ledger',
#   'rating': '8.974414613573318',
#   'vote': None,
#   'link': '/title/tt0468569/'},
#  {'movie_title': '12 Angry Men',
#   'year': '1957',
#   'place': '5',
#   'star_cast': 'Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb',
#   'rating': '8.933475530215347',
#   'vote': None,
#   'link': '/title/tt0050083/'},
#  {'movie_title': "Schindler's List",
#   'year': '1993',
#   'place': '6',
#   'star_cast': 'Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes',
#   'rating': '8.909186564646077',
#   'vote': None,
#   'link': '/title/tt0108052/'},
#  {'movie_title': 'The Lord of the Rings: The Return of the King',
#   'year': '2003',
#   'place': '7',
#   'star_cast': 'Peter Jackson (dir.), Elijah Wood, Viggo Mortensen',
#   'rating': '8.885822893752609',
#   'vote': None,
#   'link': '/title/tt0167260/'},
#  {'movie_title': 'Pulp Fiction',
#   'year': '1994',
#   'place': '8',
#   'star_cast': 'Quentin Tarantino (dir.), John Travolta, Uma Thurman',
#   'rating': '8.843299799076487',
#   'vote': None,
#   'link': '/title/tt0110912/'},
#  {'movie_title': 'Il buono, il brutto, il cattivo',
#   'year': '1966',
#   'place': '9',
#   'star_cast': 'Sergio Leone (dir.), Clint Eastwood, Eli Wallach',
#   'rating': '8.793691088990187',
#   'vote': None,
#   'link': '/title/tt0060196/'},
#  {'movie_title': ' The Lord of the Rings: The Fellowship of the Ring',
#   'year': '2001',
#   'place': '1',
#   'star_cast': 'Peter Jackson (dir.), Elijah Wood, Ian McKellen',
#   'rating': '8.777030991171936',
#   'vote': None,
#   'link': '/title/tt0120737/'},
#  {'movie_title': 'Fight Club',
#   'year': '1999',
#   'place': '11',
#   'star_cast': 'David Fincher (dir.), Brad Pitt, Edward Norton',
#   'rating': '8.764058202783648',
#   'vote': None,
#   'link': '/title/tt0137523/'},
#  {'movie_title': 'Forrest Gump',
#   'year': '1994',
#   'place': '12',
#   'star_cast': 'Robert Zemeckis (dir.), Tom Hanks, Robin Wright',
#   'rating': '8.753704788600173',
#   'vote': None,
#   'link': '/title/tt0109830/'},
#  {'movie_title': 'Inception',
#   'year': '2010',
#   'place': '13',
#   'star_cast': 'Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt',
#   'rating': '8.72080132926922',
#   'vote': None,
#   'link': '/title/tt1375666/'},
#  {'movie_title': 'The Lord of the Rings: The Two Towers',
#   'year': '2002',
#   'place': '14',
#   'star_cast': 'Peter Jackson (dir.), Elijah Wood, Ian McKellen',
#   'rating': '8.700542623530914',
#   'vote': None,
#   'link': '/title/tt0167261/'},
#  {'movie_title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'year': '1980',
#   'place': '15',
#   'star_cast': 'Irvin Kershner (dir.), Mark Hamill, Harrison Ford',
#   'rating': '8.696215609642811',
#   'vote': None,
#   'link': '/title/tt0080684/'},
#  {'movie_title': 'The Matrix',
#   'year': '1999',
#   'place': '16',
#   'star_cast': 'Lana Wachowski (dir.), Keanu Reeves, Laurence Fishburne',
#   'rating': '8.648744795418548',
#   'vote': None,
#   'link': '/title/tt0133093/'},
#  {'movie_title': 'Goodfellas',
#   'year': '1990',
#   'place': '17',
#   'star_cast': 'Martin Scorsese (dir.), Robert De Niro, Ray Liotta',
#   'rating': '8.643011268701187',
#   'vote': None,
#   'link': '/title/tt0099685/'},
#  {'movie_title': "One Flew Over the Cuckoo's Nest",
#   'year': '1975',
#   'place': '18',
#   'star_cast': 'Milos Forman (dir.), Jack Nicholson, Louise Fletcher',
#   'rating': '8.636330048975582',
#   'vote': None,
#   'link': '/title/tt0073486/'},
#  {'movie_title': 'Shichinin no samurai',
#   'year': '1954',
#   'place': '19',
#   'star_cast': 'Akira Kurosawa (dir.), Toshirô Mifune, Takashi Shimura',
#   'rating': '8.60293783004201',
#   'vote': None,
#   'link': '/title/tt0047478/'},
#  {'movie_title': 'Se7en',
#   'year': '1995',
#   'place': '20',
#   'star_cast': 'David Fincher (dir.), Morgan Freeman, Brad Pitt',
#   'rating': '8.591505653746243',
#   'vote': None,
#   'link': '/title/tt0114369/'},
#  {'movie_title': 'La vita è bella',
#   'year': '1997',
#   'place': '21',
#   'star_cast': 'Roberto Benigni (dir.), Roberto Benigni, Nicoletta Braschi',
#   'rating': '8.583651086279856',
#   'vote': None,
#   'link': '/title/tt0118799/'},
#  {'movie_title': 'Cidade de Deus',
#   'year': '2002',
#   'place': '22',
#   'star_cast': 'Fernando Meirelles (dir.), Alexandre Rodrigues, Leandro Firmino',
#   'rating': '8.57913852427613',
#   'vote': None,
#   'link': '/title/tt0317248/'},
#  {'movie_title': 'The Silence of the Lambs',
#   'year': '1991',
#   'place': '23',
#   'star_cast': 'Jonathan Demme (dir.), Jodie Foster, Anthony Hopkins',
#   'rating': '8.5754158398436',
#   'vote': None,
#   'link': '/title/tt0102926/'},
#  {'movie_title': "It's a Wonderful Life",
#   'year': '1946',
#   'place': '24',
#   'star_cast': 'Frank Capra (dir.), James Stewart, Donna Reed',
#   'rating': '8.574097798798686',
#   'vote': None,
#   'link': '/title/tt0038650/'},
#  {'movie_title': 'Star Wars',
#   'year': '1977',
#   'place': '25',
#   'star_cast': 'George Lucas (dir.), Mark Hamill, Harrison Ford',
#   'rating': '8.55258789886805',
#   'vote': None,
#   'link': '/title/tt0076759/'},
#  {'movie_title': 'Saving Private Ryan',
#   'year': '1998',
#   'place': '26',
#   'star_cast': 'Steven Spielberg (dir.), Tom Hanks, Matt Damon',
#   'rating': '8.550414158108397',
#   'vote': None,
#   'link': '/title/tt0120815/'},
#  {'movie_title': 'The Green Mile',
#   'year': '1999',
#   'place': '27',
#   'star_cast': 'Frank Darabont (dir.), Tom Hanks, Michael Clarke Duncan',
#   'rating': '8.53986271607824',
#   'vote': None,
#   'link': '/title/tt0120689/'},
#  {'movie_title': 'Sen to Chihiro no kamikakushi',
#   'year': '2001',
#   'place': '28',
#   'star_cast': 'Hayao Miyazaki (dir.), Daveigh Chase, Suzanne Pleshette',
#   'rating': '8.539200348346986',
#   'vote': None,
#   'link': '/title/tt0245429/'},
#  {'movie_title': 'Interstellar',
#   'year': '2014',
#   'place': '29',
#   'star_cast': 'Christopher Nolan (dir.), Matthew McConaughey, Anne Hathaway',
#   'rating': '8.535403872206542',
#   'vote': None,
#   'link': '/title/tt0816692/'},
#  {'movie_title': 'Gisaengchung',
#   'year': '2019',
#   'place': '30',
#   'star_cast': 'Bong Joon Ho (dir.), Kang-ho Song, Lee Sun-kyun',
#   'rating': '8.528242126510973',
#   'vote': None,
#   'link': '/title/tt6751668/'},
#  {'movie_title': 'Léon',
#   'year': '1994',
#   'place': '31',
#   'star_cast': 'Luc Besson (dir.), Jean Reno, Gary Oldman',
#   'rating': '8.508035086118488',
#   'vote': None,
#   'link': '/title/tt0110413/'},
#  {'movie_title': 'Seppuku',
#   'year': '1962',
#   'place': '32',
#   'star_cast': 'Masaki Kobayashi (dir.), Tatsuya Nakadai, Akira Ishihama',
#   'rating': '8.494940539393241',
#   'vote': None,
#   'link': '/title/tt0056058/'},
#  {'movie_title': 'The Usual Suspects',
#   'year': '1995',
#   'place': '33',
#   'star_cast': 'Bryan Singer (dir.), Kevin Spacey, Gabriel Byrne',
#   'rating': '8.494731666454808',
#   'vote': None,
#   'link': '/title/tt0114814/'},
#  {'movie_title': 'The Lion King',
#   'year': '1994',
#   'place': '34',
#   'star_cast': 'Roger Allers (dir.), Matthew Broderick, Jeremy Irons',
#   'rating': '8.491713670166115',
#   'vote': None,
#   'link': '/title/tt0110357/'},
#  {'movie_title': 'The Pianist',
#   'year': '2002',
#   'place': '35',
#   'star_cast': 'Roman Polanski (dir.), Adrien Brody, Thomas Kretschmann',
#   'rating': '8.488021169873647',
#   'vote': None,
#   'link': '/title/tt0253474/'},
#  {'movie_title': 'Back to the Future',
#   'year': '1985',
#   'place': '36',
#   'star_cast': 'Robert Zemeckis (dir.), Michael J. Fox, Christopher Lloyd',
#   'rating': '8.486691855599323',
#   'vote': None,
#   'link': '/title/tt0088763/'},
#  {'movie_title': 'Terminator 2: Judgment Day',
#   'year': '1991',
#   'place': '37',
#   'star_cast': 'James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton',
#   'rating': '8.486557916513714',
#   'vote': None,
#   'link': '/title/tt0103064/'},
#  {'movie_title': 'American History X',
#   'year': '1998',
#   'place': '38',
#   'star_cast': 'Tony Kaye (dir.), Edward Norton, Edward Furlong',
#   'rating': '8.482278073834454',
#   'vote': None,
#   'link': '/title/tt0120586/'},
#  {'movie_title': 'Modern Times',
#   'year': '1936',
#   'place': '39',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard',
#   'rating': '8.481972867278463',
#   'vote': None,
#   'link': '/title/tt0027977/'},
#  {'movie_title': 'Psycho',
#   'year': '1960',
#   'place': '40',
#   'star_cast': 'Alfred Hitchcock (dir.), Anthony Perkins, Janet Leigh',
#   'rating': '8.476854436423666',
#   'vote': None,
#   'link': '/title/tt0054215/'},
#  {'movie_title': 'Gladiator',
#   'year': '2000',
#   'place': '41',
#   'star_cast': 'Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix',
#   'rating': '8.47681216790271',
#   'vote': None,
#   'link': '/title/tt0172495/'},
#  {'movie_title': 'City Lights',
#   'year': '1931',
#   'place': '42',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Virginia Cherrill',
#   'rating': '8.472435418357586',
#   'vote': None,
#   'link': '/title/tt0021749/'},
#  {'movie_title': 'The Departed',
#   'year': '2006',
#   'place': '43',
#   'star_cast': 'Martin Scorsese (dir.), Leonardo DiCaprio, Matt Damon',
#   'rating': '8.472332478534325',
#   'vote': None,
#   'link': '/title/tt0407887/'},
#  {'movie_title': 'The Intouchables',
#   'year': '2011',
#   'place': '44',
#   'star_cast': 'Olivier Nakache (dir.), François Cluzet, Omar Sy',
#   'rating': '8.46892728376999',
#   'vote': None,
#   'link': '/title/tt1675434/'},
#  {'movie_title': 'Whiplash',
#   'year': '2014',
#   'place': '45',
#   'star_cast': 'Damien Chazelle (dir.), Miles Teller, J.K. Simmons',
#   'rating': '8.468390228808863',
#   'vote': None,
#   'link': '/title/tt2582802/'},
#  {'movie_title': 'Hotaru no haka',
#   'year': '1988',
#   'place': '46',
#   'star_cast': 'Isao Takahata (dir.), Tsutomu Tatsumi, Ayano Shiraishi',
#   'rating': '8.46058659269752',
#   'vote': None,
#   'link': '/title/tt0095327/'},
#  {'movie_title': 'The Prestige',
#   'year': '2006',
#   'place': '47',
#   'star_cast': 'Christopher Nolan (dir.), Christian Bale, Hugh Jackman',
#   'rating': '8.459682656972035',
#   'vote': None,
#   'link': '/title/tt0482571/'},
#  {'movie_title': 'Once Upon a Time in the West',
#   'year': '1968',
#   'place': '48',
#   'star_cast': 'Sergio Leone (dir.), Henry Fonda, Charles Bronson',
#   'rating': '8.445825347783321',
#   'vote': None,
#   'link': '/title/tt0064116/'},
#  {'movie_title': 'Casablanca',
#   'year': '1942',
#   'place': '49',
#   'star_cast': 'Michael Curtiz (dir.), Humphrey Bogart, Ingrid Bergman',
#   'rating': '8.436737042469616',
#   'vote': None,
#   'link': '/title/tt0034583/'},
#  {'movie_title': 'Nuovo Cinema Paradiso',
#   'year': '1988',
#   'place': '50',
#   'star_cast': 'Giuseppe Tornatore (dir.), Philippe Noiret, Enzo Cannavale',
#   'rating': '8.432514147949318',
#   'vote': None,
#   'link': '/title/tt0095765/'},
#  {'movie_title': 'Rear Window',
#   'year': '1954',
#   'place': '51',
#   'star_cast': 'Alfred Hitchcock (dir.), James Stewart, Grace Kelly',
#   'rating': '8.427439488048014',
#   'vote': None,
#   'link': '/title/tt0047396/'},
#  {'movie_title': 'Alien',
#   'year': '1979',
#   'place': '52',
#   'star_cast': 'Ridley Scott (dir.), Sigourney Weaver, Tom Skerritt',
#   'rating': '8.420637239098857',
#   'vote': None,
#   'link': '/title/tt0078748/'},
#  {'movie_title': 'Apocalypse Now',
#   'year': '1979',
#   'place': '53',
#   'star_cast': 'Francis Ford Coppola (dir.), Martin Sheen, Marlon Brando',
#   'rating': '8.417042693532972',
#   'vote': None,
#   'link': '/title/tt0078788/'},
#  {'movie_title': 'Memento',
#   'year': '2000',
#   'place': '54',
#   'star_cast': 'Christopher Nolan (dir.), Guy Pearce, Carrie-Anne Moss',
#   'rating': '8.41200339205959',
#   'vote': None,
#   'link': '/title/tt0209144/'},
#  {'movie_title': 'The Great Dictator',
#   'year': '1940',
#   'place': '55',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard',
#   'rating': '8.409383102861993',
#   'vote': None,
#   'link': '/title/tt0032553/'},
#  {'movie_title': 'Raiders of the Lost Ark',
#   'year': '1981',
#   'place': '56',
#   'star_cast': 'Steven Spielberg (dir.), Harrison Ford, Karen Allen',
#   'rating': '8.405968471123328',
#   'vote': None,
#   'link': '/title/tt0082971/'},
#  {'movie_title': 'Hamilton',
#   'year': '2020',
#   'place': '57',
#   'star_cast': 'Thomas Kail (dir.), Lin-Manuel Miranda, Phillipa Soo',
#   'rating': '8.403240836190333',
#   'vote': None,
#   'link': '/title/tt8503618/'},
#  {'movie_title': 'Django Unchained',
#   'year': '2012',
#   'place': '58',
#   'star_cast': 'Quentin Tarantino (dir.), Jamie Foxx, Christoph Waltz',
#   'rating': '8.392684890566542',
#   'vote': None,
#   'link': '/title/tt1853728/'},
#  {'movie_title': 'The Lives of Others',
#   'year': '2006',
#   'place': '59',
#   'star_cast': 'Florian Henckel von Donnersmarck (dir.), Ulrich Mühe, Martina Gedeck',
#   'rating': '8.390165627688882',
#   'vote': None,
#   'link': '/title/tt0405094/'},
#  {'movie_title': 'Paths of Glory',
#   'year': '1957',
#   'place': '60',
#   'star_cast': 'Stanley Kubrick (dir.), Kirk Douglas, Ralph Meeker',
#   'rating': '8.376697691134579',
#   'vote': None,
#   'link': '/title/tt0050825/'},
#  {'movie_title': 'Joker',
#   'year': '2019',
#   'place': '61',
#   'star_cast': 'Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro',
#   'rating': '8.376002343044396',
#   'vote': None,
#   'link': '/title/tt7286456/'},
#  {'movie_title': 'WALL·E',
#   'year': '2008',
#   'place': '62',
#   'star_cast': 'Andrew Stanton (dir.), Ben Burtt, Elissa Knight',
#   'rating': '8.370131531310161',
#   'vote': None,
#   'link': '/title/tt0910970/'},
#  {'movie_title': 'The Shining',
#   'year': '1980',
#   'place': '63',
#   'star_cast': 'Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall',
#   'rating': '8.366145063335546',
#   'vote': None,
#   'link': '/title/tt0081505/'},
#  {'movie_title': 'Avengers: Infinity War',
#   'year': '2018',
#   'place': '64',
#   'star_cast': 'Anthony Russo (dir.), Robert Downey Jr., Chris Hemsworth',
#   'rating': '8.362682922585709',
#   'vote': None,
#   'link': '/title/tt4154756/'},
#  {'movie_title': 'Sunset Blvd',
#   'year': '1950',
#   'place': '65',
#   'star_cast': 'Billy Wilder (dir.), William Holden, Gloria Swanson',
#   'rating': '8.359497657189728',
#   'vote': None,
#   'link': '/title/tt0043014/'},
#  {'movie_title': 'Witness for the Prosecution',
#   'year': '1957',
#   'place': '66',
#   'star_cast': 'Billy Wilder (dir.), Tyrone Power, Marlene Dietrich',
#   'rating': '8.3557972369666',
#   'vote': None,
#   'link': '/title/tt0051201/'},
#  {'movie_title': 'Oldeuboi',
#   'year': '2003',
#   'place': '67',
#   'star_cast': 'Chan-wook Park (dir.), Choi Min-sik, Yoo Ji-Tae',
#   'rating': '8.349749008223851',
#   'vote': None,
#   'link': '/title/tt0364569/'},
#  {'movie_title': 'Mononoke-hime',
#   'year': '1997',
#   'place': '68',
#   'star_cast': 'Hayao Miyazaki (dir.), Yôji Matsuda, Yuriko Ishida',
#   'rating': '8.349338657925479',
#   'vote': None,
#   'link': '/title/tt0119698/'},
#  {'movie_title': 'Spider-Man: Into the Spider-Verse',
#   'year': '2018',
#   'place': '69',
#   'star_cast': 'Bob Persichetti (dir.), Shameik Moore, Jake Johnson',
#   'rating': '8.348981063519217',
#   'vote': None,
#   'link': '/title/tt4633694/'},
#  {'movie_title': 'Dr Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'year': '1964',
#   'place': '70',
#   'star_cast': 'Stanley Kubrick (dir.), Peter Sellers, George C. Scott',
#   'rating': '8.346008202237918',
#   'vote': None,
#   'link': '/title/tt0057012/'},
#  {'movie_title': 'The Dark Knight Rises',
#   'year': '2012',
#   'place': '71',
#   'star_cast': 'Christopher Nolan (dir.), Christian Bale, Tom Hardy',
#   'rating': '8.331349066865021',
#   'vote': None,
#   'link': '/title/tt1345836/'},
#  {'movie_title': 'Once Upon a Time in America',
#   'year': '1984',
#   'place': '72',
#   'star_cast': 'Sergio Leone (dir.), Robert De Niro, James Woods',
#   'rating': '8.329537807936548',
#   'vote': None,
#   'link': '/title/tt0087843/'},
#  {'movie_title': 'Kimi no na wa',
#   'year': '2016',
#   'place': '73',
#   'star_cast': 'Makoto Shinkai (dir.), Ryûnosuke Kamiki, Mone Kamishiraishi',
#   'rating': '8.322485701463217',
#   'vote': None,
#   'link': '/title/tt5311514/'},
#  {'movie_title': 'Aliens',
#   'year': '1986',
#   'place': '74',
#   'star_cast': 'James Cameron (dir.), Sigourney Weaver, Michael Biehn',
#   'rating': '8.321901060543953',
#   'vote': None,
#   'link': '/title/tt0090605/'},
#  {'movie_title': 'Coco',
#   'year': '2017',
#   'place': '75',
#   'star_cast': 'Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal',
#   'rating': '8.318222068243667',
#   'vote': None,
#   'link': '/title/tt2380307/'},
#  {'movie_title': 'Avengers: Endgame',
#   'year': '2019',
#   'place': '76',
#   'star_cast': 'Anthony Russo (dir.), Robert Downey Jr., Chris Evans',
#   'rating': '8.313088578567996',
#   'vote': None,
#   'link': '/title/tt4154796/'},
#  {'movie_title': 'American Beauty',
#   'year': '1999',
#   'place': '77',
#   'star_cast': 'Sam Mendes (dir.), Kevin Spacey, Annette Bening',
#   'rating': '8.304261384038602',
#   'vote': None,
#   'link': '/title/tt0169547/'},
#  {'movie_title': 'Braveheart',
#   'year': '1995',
#   'place': '78',
#   'star_cast': 'Mel Gibson (dir.), Mel Gibson, Sophie Marceau',
#   'rating': '8.301911773467788',
#   'vote': None,
#   'link': '/title/tt0112573/'},
#  {'movie_title': 'Capharnaüm',
#   'year': '2018',
#   'place': '79',
#   'star_cast': 'Nadine Labaki (dir.), Zain Al Rafeea, Yordanos Shiferaw',
#   'rating': '8.299474990514984',
#   'vote': None,
#   'link': '/title/tt8267604/'},
#  {'movie_title': 'Das Boot',
#   'year': '1981',
#   'place': '80',
#   'star_cast': 'Wolfgang Petersen (dir.), Jürgen Prochnow, Herbert Grönemeyer',
#   'rating': '8.298596231916376',
#   'vote': None,
#   'link': '/title/tt0082096/'},
#  {'movie_title': '3 Idiots',
#   'year': '2009',
#   'place': '81',
#   'star_cast': 'Rajkumar Hirani (dir.), Aamir Khan, Madhavan',
#   'rating': '8.297610694615093',
#   'vote': None,
#   'link': '/title/tt1187043/'},
#  {'movie_title': 'Toy Story',
#   'year': '1995',
#   'place': '82',
#   'star_cast': 'John Lasseter (dir.), Tom Hanks, Tim Allen',
#   'rating': '8.297238172842947',
#   'vote': None,
#   'link': '/title/tt0114709/'},
#  {'movie_title': 'Tengoku to jigoku',
#   'year': '1963',
#   'place': '83',
#   'star_cast': 'Akira Kurosawa (dir.), Toshirô Mifune, Yutaka Sada',
#   'rating': '8.295212572681013',
#   'vote': None,
#   'link': '/title/tt0057565/'},
#  {'movie_title': 'Amadeus',
#   'year': '1984',
#   'place': '84',
#   'star_cast': 'Milos Forman (dir.), F. Murray Abraham, Tom Hulce',
#   'rating': '8.290375079096002',
#   'vote': None,
#   'link': '/title/tt0086879/'},
#  {'movie_title': 'Inglourious Basterds',
#   'year': '2009',
#   'place': '85',
#   'star_cast': 'Quentin Tarantino (dir.), Brad Pitt, Diane Kruger',
#   'rating': '8.287070731915152',
#   'vote': None,
#   'link': '/title/tt0361748/'},
#  {'movie_title': 'Star Wars: Episode VI - Return of the Jedi',
#   'year': '1983',
#   'place': '86',
#   'star_cast': 'Richard Marquand (dir.), Mark Hamill, Harrison Ford',
#   'rating': '8.28375312454849',
#   'vote': None,
#   'link': '/title/tt0086190/'},
#  {'movie_title': 'Good Will Hunting',
#   'year': '1997',
#   'place': '87',
#   'star_cast': 'Gus Van Sant (dir.), Robin Williams, Matt Damon',
#   'rating': '8.282559512876933',
#   'vote': None,
#   'link': '/title/tt0119217/'},
#  {'movie_title': 'Taare Zameen Par',
#   'year': '2007',
#   'place': '88',
#   'star_cast': 'Aamir Khan (dir.), Darsheel Safary, Aamir Khan',
#   'rating': '8.281979701671041',
#   'vote': None,
#   'link': '/title/tt0986264/'},
#  {'movie_title': 'Reservoir Dogs',
#   'year': '1992',
#   'place': '89',
#   'star_cast': 'Quentin Tarantino (dir.), Harvey Keitel, Tim Roth',
#   'rating': '8.278797038424935',
#   'vote': None,
#   'link': '/title/tt0105236/'},
#  {'movie_title': '2001: A Space Odyssey',
#   'year': '1968',
#   'place': '90',
#   'star_cast': 'Stanley Kubrick (dir.), Keir Dullea, Gary Lockwood',
#   'rating': '8.268848117693304',
#   'vote': None,
#   'link': '/title/tt0062622/'},
#  {'movie_title': 'Requiem for a Dream',
#   'year': '2000',
#   'place': '91',
#   'star_cast': 'Darren Aronofsky (dir.), Ellen Burstyn, Jared Leto',
#   'rating': '8.2654926959951',
#   'vote': None,
#   'link': '/title/tt0180093/'},
#  {'movie_title': 'Vertigo',
#   'year': '1958',
#   'place': '92',
#   'star_cast': 'Alfred Hitchcock (dir.), James Stewart, Kim Novak',
#   'rating': '8.261832487408784',
#   'vote': None,
#   'link': '/title/tt0052357/'},
#  {'movie_title': 'M - Eine Stadt sucht einen Mörder',
#   'year': '1931',
#   'place': '93',
#   'star_cast': 'Fritz Lang (dir.), Peter Lorre, Ellen Widmann',
#   'rating': '8.261815845576194',
#   'vote': None,
#   'link': '/title/tt0022100/'},
#  {'movie_title': 'Jagten',
#   'year': '2012',
#   'place': '94',
#   'star_cast': 'Thomas Vinterberg (dir.), Mads Mikkelsen, Thomas Bo Larsen',
#   'rating': '8.260761249656944',
#   'vote': None,
#   'link': '/title/tt2106476/'},
#  {'movie_title': 'Eternal Sunshine of the Spotless Mind',
#   'year': '2004',
#   'place': '95',
#   'star_cast': 'Michel Gondry (dir.), Jim Carrey, Kate Winslet',
#   'rating': '8.258022055734163',
#   'vote': None,
#   'link': '/title/tt0338013/'},
#  {'movie_title': 'Citizen Kane',
#   'year': '1941',
#   'place': '96',
#   'star_cast': 'Orson Welles (dir.), Orson Welles, Joseph Cotten',
#   'rating': '8.25531031684111',
#   'vote': None,
#   'link': '/title/tt0033467/'},
#  {'movie_title': 'Dangal',
#   'year': '2016',
#   'place': '97',
#   'star_cast': 'Nitesh Tiwari (dir.), Aamir Khan, Sakshi Tanwar',
#   'rating': '8.254360478174483',
#   'vote': None,
#   'link': '/title/tt5074352/'},
#  {'movie_title': 'Full Metal Jacket',
#   'year': '1987',
#   'place': '98',
#   'star_cast': 'Stanley Kubrick (dir.), Matthew Modine, R. Lee Ermey',
#   'rating': '8.246650646300221',
#   'vote': None,
#   'link': '/title/tt0093058/'},
#  {'movie_title': 'Ladri di biciclette',
#   'year': '1948',
#   'place': '99',
#   'star_cast': 'Vittorio De Sica (dir.), Lamberto Maggiorani, Enzo Staiola',
#   'rating': '8.246560727648763',
#   'vote': None,
#   'link': '/title/tt0040522/'},
#  {'movie_title': " Singin' in the Rain",
#   'year': '1952',
#   'place': '10',
#   'star_cast': "Stanley Donen (dir.), Gene Kelly, Donald O'Connor",
#   'rating': '8.246379406057104',
#   'vote': None,
#   'link': '/title/tt0045152/'},
#  {'movie_title': 'The Kid',
#   'year': '1921',
#   'place': '101',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Edna Purviance',
#   'rating': '8.245988476048016',
#   'vote': None,
#   'link': '/title/tt0012349/'},
#  {'movie_title': 'Snatch',
#   'year': '2000',
#   'place': '102',
#   'star_cast': 'Guy Ritchie (dir.), Jason Statham, Brad Pitt',
#   'rating': '8.242848072117114',
#   'vote': None,
#   'link': '/title/tt0208092/'},
#  {'movie_title': 'North by Northwest',
#   'year': '1959',
#   'place': '103',
#   'star_cast': 'Alfred Hitchcock (dir.), Cary Grant, Eva Marie Saint',
#   'rating': '8.24262538744088',
#   'vote': None,
#   'link': '/title/tt0053125/'},
#  {'movie_title': 'A Clockwork Orange',
#   'year': '1971',
#   'place': '104',
#   'star_cast': 'Stanley Kubrick (dir.), Malcolm McDowell, Patrick Magee',
#   'rating': '8.24215592426274',
#   'vote': None,
#   'link': '/title/tt0066921/'},
#  {'movie_title': 'Scarface',
#   'year': '1983',
#   'place': '105',
#   'star_cast': 'Brian De Palma (dir.), Al Pacino, Michelle Pfeiffer',
#   'rating': '8.241363635343546',
#   'vote': None,
#   'link': '/title/tt0086250/'},
#  {'movie_title': '1917',
#   'year': '2019',
#   'place': '106',
#   'star_cast': 'Sam Mendes (dir.), Dean-Charles Chapman, George MacKay',
#   'rating': '8.241227678022751',
#   'vote': None,
#   'link': '/title/tt8579674/'},
#  {'movie_title': 'Idi i smotri',
#   'year': '1985',
#   'place': '107',
#   'star_cast': 'Elem Klimov (dir.), Aleksey Kravchenko, Olga Mironova',
#   'rating': '8.240291869284206',
#   'vote': None,
#   'link': '/title/tt0091251/'},
#  {'movie_title': 'Ikiru',
#   'year': '1952',
#   'place': '108',
#   'star_cast': 'Akira Kurosawa (dir.), Takashi Shimura, Nobuo Kaneko',
#   'rating': '8.239556428303684',
#   'vote': None,
#   'link': '/title/tt0044741/'},
#  {'movie_title': 'Taxi Driver',
#   'year': '1976',
#   'place': '109',
#   'star_cast': 'Martin Scorsese (dir.), Robert De Niro, Jodie Foster',
#   'rating': '8.235820488231804',
#   'vote': None,
#   'link': '/title/tt0075314/'},
#  {'movie_title': 'Toy Story 3',
#   'year': '2010',
#   'place': '110',
#   'star_cast': 'Lee Unkrich (dir.), Tom Hanks, Tim Allen',
#   'rating': '8.231470839757858',
#   'vote': None,
#   'link': '/title/tt0435761/'},
#  {'movie_title': 'Lawrence of Arabia',
#   'year': '1962',
#   'place': '111',
#   'star_cast': "David Lean (dir.), Peter O'Toole, Alec Guinness",
#   'rating': '8.231436707897547',
#   'vote': None,
#   'link': '/title/tt0056172/'},
#  {'movie_title': 'Jodaeiye Nader az Simin',
#   'year': '2011',
#   'place': '112',
#   'star_cast': 'Asghar Farhadi (dir.), Payman Maadi, Leila Hatami',
#   'rating': '8.231153439759115',
#   'vote': None,
#   'link': '/title/tt1832382/'},
#  {'movie_title': 'Amélie',
#   'year': '2001',
#   'place': '113',
#   'star_cast': 'Jean-Pierre Jeunet (dir.), Audrey Tautou, Mathieu Kassovitz',
#   'rating': '8.230974446417775',
#   'vote': None,
#   'link': '/title/tt0211915/'},
#  {'movie_title': 'Incendies',
#   'year': '2010',
#   'place': '114',
#   'star_cast': 'Denis Villeneuve (dir.), Lubna Azabal, Mélissa Désormeaux-Poulin',
#   'rating': '8.230970169321884',
#   'vote': None,
#   'link': '/title/tt1255953/'},
#  {'movie_title': 'The Sting',
#   'year': '1973',
#   'place': '115',
#   'star_cast': 'George Roy Hill (dir.), Paul Newman, Robert Redford',
#   'rating': '8.230763055148767',
#   'vote': None,
#   'link': '/title/tt0070735/'},
#  {'movie_title': 'Metropolis',
#   'year': '1927',
#   'place': '116',
#   'star_cast': 'Fritz Lang (dir.), Brigitte Helm, Alfred Abel',
#   'rating': '8.22971834462941',
#   'vote': None,
#   'link': '/title/tt0017136/'},
#  {'movie_title': 'Per qualche dollaro in più',
#   'year': '1965',
#   'place': '117',
#   'star_cast': 'Sergio Leone (dir.), Clint Eastwood, Lee Van Cleef',
#   'rating': '8.225581911058667',
#   'vote': None,
#   'link': '/title/tt0059578/'},
#  {'movie_title': 'The Apartment',
#   'year': '1960',
#   'place': '118',
#   'star_cast': 'Billy Wilder (dir.), Jack Lemmon, Shirley MacLaine',
#   'rating': '8.225078876405489',
#   'vote': None,
#   'link': '/title/tt0053604/'},
#  {'movie_title': 'Double Indemnity',
#   'year': '1944',
#   'place': '119',
#   'star_cast': 'Billy Wilder (dir.), Fred MacMurray, Barbara Stanwyck',
#   'rating': '8.22026416779114',
#   'vote': None,
#   'link': '/title/tt0036775/'},
#  {'movie_title': 'To Kill a Mockingbird',
#   'year': '1962',
#   'place': '120',
#   'star_cast': 'Robert Mulligan (dir.), Gregory Peck, John Megna',
#   'rating': '8.213923621271029',
#   'vote': None,
#   'link': '/title/tt0056592/'},
#  {'movie_title': 'Up',
#   'year': '2009',
#   'place': '121',
#   'star_cast': 'Pete Docter (dir.), Edward Asner, Jordan Nagai',
#   'rating': '8.212343529065038',
#   'vote': None,
#   'link': '/title/tt1049413/'},
#  {'movie_title': 'Indiana Jones and the Last Crusade',
#   'year': '1989',
#   'place': '122',
#   'star_cast': 'Steven Spielberg (dir.), Harrison Ford, Sean Connery',
#   'rating': '8.20988429941914',
#   'vote': None,
#   'link': '/title/tt0097576/'},
#  {'movie_title': 'Heat',
#   'year': '1995',
#   'place': '123',
#   'star_cast': 'Michael Mann (dir.), Al Pacino, Robert De Niro',
#   'rating': '8.201692530978693',
#   'vote': None,
#   'link': '/title/tt0113277/'},
#  {'movie_title': 'LA Confidential',
#   'year': '1997',
#   'place': '124',
#   'star_cast': 'Curtis Hanson (dir.), Kevin Spacey, Russell Crowe',
#   'rating': '8.200213820433367',
#   'vote': None,
#   'link': '/title/tt0119488/'},
#  {'movie_title': 'Die Hard',
#   'year': '1988',
#   'place': '125',
#   'star_cast': 'John McTiernan (dir.), Bruce Willis, Alan Rickman',
#   'rating': '8.193513111548663',
#   'vote': None,
#   'link': '/title/tt0095016/'},
#  {'movie_title': 'Green Book',
#   'year': '2018',
#   'place': '126',
#   'star_cast': 'Peter Farrelly (dir.), Viggo Mortensen, Mahershala Ali',
#   'rating': '8.192646061153177',
#   'vote': None,
#   'link': '/title/tt6966692/'},
#  {'movie_title': 'Monty Python and the Holy Grail',
#   'year': '1975',
#   'place': '127',
#   'star_cast': 'Terry Gilliam (dir.), Graham Chapman, John Cleese',
#   'rating': '8.189767116559903',
#   'vote': None,
#   'link': '/title/tt0071853/'},
#  {'movie_title': 'Batman Begins',
#   'year': '2005',
#   'place': '128',
#   'star_cast': 'Christopher Nolan (dir.), Christian Bale, Michael Caine',
#   'rating': '8.188658392595736',
#   'vote': None,
#   'link': '/title/tt0372784/'},
#  {'movie_title': 'Yôjinbô',
#   'year': '1961',
#   'place': '129',
#   'star_cast': 'Akira Kurosawa (dir.), Toshirô Mifune, Eijirô Tôno',
#   'rating': '8.18860168804074',
#   'vote': None,
#   'link': '/title/tt0055630/'},
#  {'movie_title': 'Rashômon',
#   'year': '1950',
#   'place': '130',
#   'star_cast': 'Akira Kurosawa (dir.), Toshirô Mifune, Machiko Kyô',
#   'rating': '8.188145711240995',
#   'vote': None,
#   'link': '/title/tt0042876/'},
#  {'movie_title': 'Der Untergang',
#   'year': '2004',
#   'place': '131',
#   'star_cast': 'Oliver Hirschbiegel (dir.), Bruno Ganz, Alexandra Maria Lara',
#   'rating': '8.185560742273342',
#   'vote': None,
#   'link': '/title/tt0363163/'},
#  {'movie_title': 'Bacheha-Ye aseman',
#   'year': '1997',
#   'place': '132',
#   'star_cast': 'Majid Majidi (dir.), Mohammad Amir Naji, Amir Farrokh Hashemian',
#   'rating': '8.183676532092084',
#   'vote': None,
#   'link': '/title/tt0118849/'},
#  {'movie_title': 'Unforgiven',
#   'year': '1992',
#   'place': '133',
#   'star_cast': 'Clint Eastwood (dir.), Clint Eastwood, Gene Hackman',
#   'rating': '8.177835132125711',
#   'vote': None,
#   'link': '/title/tt0105695/'},
#  {'movie_title': 'Ran',
#   'year': '1985',
#   'place': '134',
#   'star_cast': 'Akira Kurosawa (dir.), Tatsuya Nakadai, Akira Terao',
#   'rating': '8.175744889888477',
#   'vote': None,
#   'link': '/title/tt0089881/'},
#  {'movie_title': 'Some Like It Hot',
#   'year': '1959',
#   'place': '135',
#   'star_cast': 'Billy Wilder (dir.), Marilyn Monroe, Tony Curtis',
#   'rating': '8.175617844617053',
#   'vote': None,
#   'link': '/title/tt0053291/'},
#  {'movie_title': 'Hauru no ugoku shiro',
#   'year': '2004',
#   'place': '136',
#   'star_cast': 'Hayao Miyazaki (dir.), Chieko Baishô, Takuya Kimura',
#   'rating': '8.165328181672876',
#   'vote': None,
#   'link': '/title/tt0347149/'},
#  {'movie_title': 'All About Eve',
#   'year': '1950',
#   'place': '137',
#   'star_cast': 'Joseph L. Mankiewicz (dir.), Bette Davis, Anne Baxter',
#   'rating': '8.160912367376126',
#   'vote': None,
#   'link': '/title/tt0042192/'},
#  {'movie_title': 'Casino',
#   'year': '1995',
#   'place': '138',
#   'star_cast': 'Martin Scorsese (dir.), Robert De Niro, Sharon Stone',
#   'rating': '8.15971848995418',
#   'vote': None,
#   'link': '/title/tt0112641/'},
#  {'movie_title': 'A Beautiful Mind',
#   'year': '2001',
#   'place': '139',
#   'star_cast': 'Ron Howard (dir.), Russell Crowe, Ed Harris',
#   'rating': '8.159712120886814',
#   'vote': None,
#   'link': '/title/tt0268978/'},
#  {'movie_title': 'The Great Escape',
#   'year': '1963',
#   'place': '140',
#   'star_cast': 'John Sturges (dir.), Steve McQueen, James Garner',
#   'rating': '8.157877043308789',
#   'vote': None,
#   'link': '/title/tt0057115/'},
#  {'movie_title': 'The Wolf of Wall Street',
#   'year': '2013',
#   'place': '141',
#   'star_cast': 'Martin Scorsese (dir.), Leonardo DiCaprio, Jonah Hill',
#   'rating': '8.157361750560067',
#   'vote': None,
#   'link': '/title/tt0993846/'},
#  {'movie_title': "Pan's Labyrinth",
#   'year': '2006',
#   'place': '142',
#   'star_cast': 'Guillermo del Toro (dir.), Ivana Baquero, Ariadna Gil',
#   'rating': '8.152614336060847',
#   'vote': None,
#   'link': '/title/tt0457430/'},
#  {'movie_title': 'El secreto de sus ojos',
#   'year': '2009',
#   'place': '143',
#   'star_cast': 'Juan José Campanella (dir.), Ricardo Darín, Soledad Villamil',
#   'rating': '8.148554909994228',
#   'vote': None,
#   'link': '/title/tt1305806/'},
#  {'movie_title': 'There Will Be Blood',
#   'year': '2007',
#   'place': '144',
#   'star_cast': 'Paul Thomas Anderson (dir.), Daniel Day-Lewis, Paul Dano',
#   'rating': '8.14787423745005',
#   'vote': None,
#   'link': '/title/tt0469494/'},
#  {'movie_title': 'Lock, Stock and Two Smoking Barrels',
#   'year': '1998',
#   'place': '145',
#   'star_cast': 'Guy Ritchie (dir.), Jason Flemyng, Dexter Fletcher',
#   'rating': '8.146138157306403',
#   'vote': None,
#   'link': '/title/tt0120735/'},
#  {'movie_title': 'Tonari no Totoro',
#   'year': '1988',
#   'place': '146',
#   'star_cast': 'Hayao Miyazaki (dir.), Hitoshi Takagi, Noriko Hidaka',
#   'rating': '8.143014081656545',
#   'vote': None,
#   'link': '/title/tt0096283/'},
#  {'movie_title': 'Judgment at Nuremberg',
#   'year': '1961',
#   'place': '147',
#   'star_cast': 'Stanley Kramer (dir.), Spencer Tracy, Burt Lancaster',
#   'rating': '8.142813325249662',
#   'vote': None,
#   'link': '/title/tt0055031/'},
#  {'movie_title': 'Raging Bull',
#   'year': '1980',
#   'place': '148',
#   'star_cast': 'Martin Scorsese (dir.), Robert De Niro, Cathy Moriarty',
#   'rating': '8.142431518878237',
#   'vote': None,
#   'link': '/title/tt0081398/'},
#  {'movie_title': 'The Treasure of the Sierra Madre',
#   'year': '1948',
#   'place': '149',
#   'star_cast': 'John Huston (dir.), Humphrey Bogart, Walter Huston',
#   'rating': '8.137660842985401',
#   'vote': None,
#   'link': '/title/tt0040897/'},
#  {'movie_title': 'Dial M for Murder',
#   'year': '1954',
#   'place': '150',
#   'star_cast': 'Alfred Hitchcock (dir.), Ray Milland, Grace Kelly',
#   'rating': '8.131975550528901',
#   'vote': None,
#   'link': '/title/tt0046912/'},
#  {'movie_title': 'Three Billboards Outside Ebbing, Missouri',
#   'year': '2017',
#   'place': '151',
#   'star_cast': 'Martin McDonagh (dir.), Frances McDormand, Woody Harrelson',
#   'rating': '8.130468093184497',
#   'vote': None,
#   'link': '/title/tt5027774/'},
#  {'movie_title': 'Shutter Island',
#   'year': '2010',
#   'place': '152',
#   'star_cast': 'Martin Scorsese (dir.), Leonardo DiCaprio, Emily Mortimer',
#   'rating': '8.12908555359521',
#   'vote': None,
#   'link': '/title/tt1130884/'},
#  {'movie_title': 'Chinatown',
#   'year': '1974',
#   'place': '153',
#   'star_cast': 'Roman Polanski (dir.), Jack Nicholson, Faye Dunaway',
#   'rating': '8.12659339185813',
#   'vote': None,
#   'link': '/title/tt0071315/'},
#  {'movie_title': 'The Gold Rush',
#   'year': '1925',
#   'place': '154',
#   'star_cast': 'Charles Chaplin (dir.), Charles Chaplin, Mack Swain',
#   'rating': '8.126558656931968',
#   'vote': None,
#   'link': '/title/tt0015864/'},
#  {'movie_title': 'Babam ve Oglum',
#   'year': '2005',
#   'place': '155',
#   'star_cast': 'Veysel Aslan (dir.), Eser Sariyar, Çetin Tekindor',
#   'rating': '8.12509354883672',
#   'vote': None,
#   'link': '/title/tt0476735/'},
#  {'movie_title': 'No Country for Old Men',
#   'year': '2007',
#   'place': '156',
#   'star_cast': 'Ethan Coen (dir.), Tommy Lee Jones, Javier Bardem',
#   'rating': '8.124693329935754',
#   'vote': None,
#   'link': '/title/tt0477348/'},
#  {'movie_title': 'V for Vendetta',
#   'year': '2005',
#   'place': '157',
#   'star_cast': 'James McTeigue (dir.), Hugo Weaving, Natalie Portman',
#   'rating': '8.123053559190735',
#   'vote': None,
#   'link': '/title/tt0434409/'},
#  {'movie_title': 'Inside Out',
#   'year': '2015',
#   'place': '158',
#   'star_cast': 'Pete Docter (dir.), Amy Poehler, Bill Hader',
#   'rating': '8.120519343576714',
#   'vote': None,
#   'link': '/title/tt2096673/'},
#  {'movie_title': 'Det sjunde inseglet',
#   'year': '1957',
#   'place': '159',
#   'star_cast': 'Ingmar Bergman (dir.), Max von Sydow, Gunnar Björnstrand',
#   'rating': '8.118937140007738',
#   'vote': None,
#   'link': '/title/tt0050976/'},
#  {'movie_title': 'The Elephant Man',
#   'year': '1980',
#   'place': '160',
#   'star_cast': 'David Lynch (dir.), Anthony Hopkins, John Hurt',
#   'rating': '8.11893519095133',
#   'vote': None,
#   'link': '/title/tt0080678/'},
#  {'movie_title': 'The Thing',
#   'year': '1982',
#   'place': '161',
#   'star_cast': 'John Carpenter (dir.), Kurt Russell, Wilford Brimley',
#   'rating': '8.118569993879765',
#   'vote': None,
#   'link': '/title/tt0084787/'},
#  {'movie_title': 'Warrior',
#   'year': '2011',
#   'place': '162',
#   'star_cast': "Gavin O'Connor (dir.), Tom Hardy, Nick Nolte",
#   'rating': '8.117418693112356',
#   'vote': None,
#   'link': '/title/tt1291584/'},
#  {'movie_title': 'The Sixth Sense',
#   'year': '1999',
#   'place': '163',
#   'star_cast': 'M. Night Shyamalan (dir.), Bruce Willis, Haley Joel Osment',
#   'rating': '8.11614658050397',
#   'vote': None,
#   'link': '/title/tt0167404/'},
#  {'movie_title': 'Trainspotting',
#   'year': '1996',
#   'place': '164',
#   'star_cast': 'Danny Boyle (dir.), Ewan McGregor, Ewen Bremner',
#   'rating': '8.11503628735438',
#   'vote': None,
#   'link': '/title/tt0117951/'},
#  {'movie_title': 'Jurassic Park',
#   'year': '1993',
#   'place': '165',
#   'star_cast': 'Steven Spielberg (dir.), Sam Neill, Laura Dern',
#   'rating': '8.114440967822858',
#   'vote': None,
#   'link': '/title/tt0107290/'},
#  {'movie_title': 'Klaus',
#   'year': '2019',
#   'place': '166',
#   'star_cast': 'Sergio Pablos (dir.), Jason Schwartzman, J.K. Simmons',
#   'rating': '8.112365634442664',
#   'vote': None,
#   'link': '/title/tt4729430/'},
#  {'movie_title': 'The Truman Show',
#   'year': '1998',
#   'place': '167',
#   'star_cast': 'Peter Weir (dir.), Jim Carrey, Ed Harris',
#   'rating': '8.10991086345543',
#   'vote': None,
#   'link': '/title/tt0120382/'},
#  {'movie_title': 'Gone with the Wind',
#   'year': '1939',
#   'place': '168',
#   'star_cast': 'Victor Fleming (dir.), Clark Gable, Vivien Leigh',
#   'rating': '8.107405058403494',
#   'vote': None,
#   'link': '/title/tt0031381/'},
#  {'movie_title': 'Finding Nemo',
#   'year': '2003',
#   'place': '169',
#   'star_cast': 'Andrew Stanton (dir.), Albert Brooks, Ellen DeGeneres',
#   'rating': '8.105637522250696',
#   'vote': None,
#   'link': '/title/tt0266543/'},
#  {'movie_title': 'Smultronstället',
#   'year': '1957',
#   'place': '170',
#   'star_cast': 'Ingmar Bergman (dir.), Victor Sjöström, Bibi Andersson',
#   'rating': '8.104672610346634',
#   'vote': None,
#   'link': '/title/tt0050986/'},
#  {'movie_title': 'Blade Runner',
#   'year': '1982',
#   'place': '171',
#   'star_cast': 'Ridley Scott (dir.), Harrison Ford, Rutger Hauer',
#   'rating': '8.103328822016282',
#   'vote': None,
#   'link': '/title/tt0083658/'},
#  {'movie_title': 'Stalker',
#   'year': '1979',
#   'place': '172',
#   'star_cast': 'Andrei Tarkovsky (dir.), Alisa Freyndlikh, Aleksandr Kaydanovskiy',
#   'rating': '8.103239787283645',
#   'vote': None,
#   'link': '/title/tt0079944/'},
#  {'movie_title': 'Kill Bill: Vol 1',
#   'year': '2003',
#   'place': '173',
#   'star_cast': 'Quentin Tarantino (dir.), Uma Thurman, David Carradine',
#   'rating': '8.102772560698833',
#   'vote': None,
#   'link': '/title/tt0266697/'},
#  {'movie_title': 'Salinui chueok',
#   'year': '2003',
#   'place': '174',
#   'star_cast': 'Bong Joon Ho (dir.), Kang-ho Song, Kim Sang-kyung',
#   'rating': '8.101308390022869',
#   'vote': None,
#   'link': '/title/tt0353969/'},
#  {'movie_title': 'Fargo',
#   'year': '1996',
#   'place': '175',
#   'star_cast': 'Joel Coen (dir.), William H. Macy, Frances McDormand',
#   'rating': '8.099399549861916',
#   'vote': None,
#   'link': '/title/tt0116282/'},
#  {'movie_title': 'The Bridge on the River Kwai',
#   'year': '1957',
#   'place': '176',
#   'star_cast': 'David Lean (dir.), William Holden, Alec Guinness',
#   'rating': '8.099266611741285',
#   'vote': None,
#   'link': '/title/tt0050212/'},
#  {'movie_title': 'Room',
#   'year': '2015',
#   'place': '177',
#   'star_cast': 'Lenny Abrahamson (dir.), Brie Larson, Jacob Tremblay',
#   'rating': '8.095711755937261',
#   'vote': None,
#   'link': '/title/tt3170832/'},
#  {'movie_title': 'Relatos salvajes',
#   'year': '2014',
#   'place': '178',
#   'star_cast': 'Damián Szifron (dir.), Darío Grandinetti, María Marull',
#   'rating': '8.093492255472206',
#   'vote': None,
#   'link': '/title/tt3011894/'},
#  {'movie_title': 'Gran Torino',
#   'year': '2008',
#   'place': '179',
#   'star_cast': 'Clint Eastwood (dir.), Clint Eastwood, Bee Vang',
#   'rating': '8.093299378984797',
#   'vote': None,
#   'link': '/title/tt1205489/'},
#  {'movie_title': 'The Third Man',
#   'year': '1949',
#   'place': '180',
#   'star_cast': 'Carol Reed (dir.), Orson Welles, Joseph Cotten',
#   'rating': '8.09301570840198',
#   'vote': None,
#   'link': '/title/tt0041959/'},
#  {'movie_title': 'Tôkyô monogatari',
#   'year': '1953',
#   'place': '181',
#   'star_cast': 'Yasujirô Ozu (dir.), Chishû Ryû, Chieko Higashiyama',
#   'rating': '8.09191727697077',
#   'vote': None,
#   'link': '/title/tt0046438/'},
#  {'movie_title': 'On the Waterfront',
#   'year': '1954',
#   'place': '182',
#   'star_cast': 'Elia Kazan (dir.), Marlon Brando, Karl Malden',
#   'rating': '8.091706080415985',
#   'vote': None,
#   'link': '/title/tt0047296/'},
#  {'movie_title': 'The Deer Hunter',
#   'year': '1978',
#   'place': '183',
#   'star_cast': 'Michael Cimino (dir.), Robert De Niro, Christopher Walken',
#   'rating': '8.090577201896314',
#   'vote': None,
#   'link': '/title/tt0077416/'},
#  {'movie_title': 'In the Name of the Father',
#   'year': '1993',
#   'place': '184',
#   'star_cast': 'Jim Sheridan (dir.), Daniel Day-Lewis, Pete Postlethwaite',
#   'rating': '8.086025755475594',
#   'vote': None,
#   'link': '/title/tt0107207/'},
#  {'movie_title': 'Mary and Max',
#   'year': '2009',
#   'place': '185',
#   'star_cast': 'Adam Elliot (dir.), Toni Collette, Philip Seymour Hoffman',
#   'rating': '8.084421920954192',
#   'vote': None,
#   'link': '/title/tt0978762/'},
#  {'movie_title': 'The Grand Budapest Hotel',
#   'year': '2014',
#   'place': '186',
#   'star_cast': 'Wes Anderson (dir.), Ralph Fiennes, F. Murray Abraham',
#   'rating': '8.08283298138871',
#   'vote': None,
#   'link': '/title/tt2278388/'},
#  {'movie_title': 'Gone Girl',
#   'year': '2014',
#   'place': '187',
#   'star_cast': 'David Fincher (dir.), Ben Affleck, Rosamund Pike',
#   'rating': '8.082384390166984',
#   'vote': None,
#   'link': '/title/tt2267998/'},
#  {'movie_title': 'Before Sunrise',
#   'year': '1995',
#   'place': '188',
#   'star_cast': 'Richard Linklater (dir.), Ethan Hawke, Julie Delpy',
#   'rating': '8.082277926006109',
#   'vote': None,
#   'link': '/title/tt0112471/'},
#  {'movie_title': 'Anand',
#   'year': '1971',
#   'place': '189',
#   'star_cast': 'Hrishikesh Mukherjee (dir.), Rajesh Khanna, Amitabh Bachchan',
#   'rating': '8.082157223921117',
#   'vote': None,
#   'link': '/title/tt0066763/'},
#  {'movie_title': 'Catch Me If You Can',
#   'year': '2002',
#   'place': '190',
#   'star_cast': 'Steven Spielberg (dir.), Leonardo DiCaprio, Tom Hanks',
#   'rating': '8.08147796997717',
#   'vote': None,
#   'link': '/title/tt0264464/'},
#  {'movie_title': 'Hacksaw Ridge',
#   'year': '2016',
#   'place': '191',
#   'star_cast': 'Mel Gibson (dir.), Andrew Garfield, Sam Worthington',
#   'rating': '8.0808754412333',
#   'vote': None,
#   'link': '/title/tt2119532/'},
#  {'movie_title': 'Persona',
#   'year': '1966',
#   'place': '192',
#   'star_cast': 'Ingmar Bergman (dir.), Bibi Andersson, Liv Ullmann',
#   'rating': '8.07746623302454',
#   'vote': None,
#   'link': '/title/tt0060827/'},
#  {'movie_title': 'Prisoners',
#   'year': '2013',
#   'place': '193',
#   'star_cast': 'Denis Villeneuve (dir.), Hugh Jackman, Jake Gyllenhaal',
#   'rating': '8.077165559248172',
#   'vote': None,
#   'link': '/title/tt1392214/'},
#  {'movie_title': 'Andhadhun',
#   'year': '2018',
#   'place': '194',
#   'star_cast': 'Sriram Raghavan (dir.), Ayushmann Khurrana, Tabu',
#   'rating': '8.076516730446501',
#   'vote': None,
#   'link': '/title/tt8108198/'},
#  {'movie_title': 'Höstsonaten',
#   'year': '1978',
#   'place': '195',
#   'star_cast': 'Ingmar Bergman (dir.), Ingrid Bergman, Liv Ullmann',
#   'rating': '8.075554520101331',
#   'vote': None,
#   'link': '/title/tt0077711/'},
#  {'movie_title': 'The Big Lebowski',
#   'year': '1998',
#   'place': '196',
#   'star_cast': 'Joel Coen (dir.), Jeff Bridges, John Goodman',
#   'rating': '8.074478219391453',
#   'vote': None,
#   'link': '/title/tt0118715/'},
#  {'movie_title': 'Sherlock Jr',
#   'year': '1924',
#   'place': '197',
#   'star_cast': 'Buster Keaton (dir.), Buster Keaton, Kathryn McGuire',
#   'rating': '8.0732181124631',
#   'vote': None,
#   'link': '/title/tt0015324/'},
#  {'movie_title': 'To Be or Not to Be',
#   'year': '1942',
#   'place': '198',
#   'star_cast': 'Ernst Lubitsch (dir.), Carole Lombard, Jack Benny',
#   'rating': '8.07050183093001',
#   'vote': None,
#   'link': '/title/tt0035446/'},
#  {'movie_title': 'The General',
#   'year': '1926',
#   'place': '199',
#   'star_cast': 'Clyde Bruckman (dir.), Buster Keaton, Marion Mack',
#   'rating': '8.069541254450062',
#   'vote': None,
#   'link': '/title/tt0017925/'},
#  {'movie_title': 'How to Train Your Dragon',
#   'year': '2010',
#   'place': '200',
#   'star_cast': 'Dean DeBlois (dir.), Jay Baruchel, Gerard Butler',
#   'rating': '8.069423377026665',
#   'vote': None,
#   'link': '/title/tt0892769/'},
#  {'movie_title': 'Ford v Ferrari',
#   'year': '2019',
#   'place': '201',
#   'star_cast': 'James Mangold (dir.), Matt Damon, Christian Bale',
#   'rating': '8.068593562984544',
#   'vote': None,
#   'link': '/title/tt1950186/'},
#  {'movie_title': 'Barry Lyndon',
#   'year': '1975',
#   'place': '202',
#   'star_cast': "Stanley Kubrick (dir.), Ryan O'Neal, Marisa Berenson",
#   'rating': '8.068367344860517',
#   'vote': None,
#   'link': '/title/tt0072684/'},
#  {'movie_title': '12 Years a Slave',
#   'year': '2013',
#   'place': '203',
#   'star_cast': 'Steve McQueen (dir.), Chiwetel Ejiofor, Michael Kenneth Williams',
#   'rating': '8.067114567919736',
#   'vote': None,
#   'link': '/title/tt2024544/'},
#  {'movie_title': 'Eskiya',
#   'year': '1996',
#   'place': '204',
#   'star_cast': 'Yavuz Turgul (dir.), Sener Sen, Ugur Yücel',
#   'rating': '8.066565211411309',
#   'vote': None,
#   'link': '/title/tt0116231/'},
#  {'movie_title': 'Mr Smith Goes to Washington',
#   'year': '1939',
#   'place': '205',
#   'star_cast': 'Frank Capra (dir.), James Stewart, Jean Arthur',
#   'rating': '8.065064437606972',
#   'vote': None,
#   'link': '/title/tt0031679/'},
#  {'movie_title': 'Soul',
#   'year': '2020',
#   'place': '206',
#   'star_cast': 'Pete Docter (dir.), Jamie Foxx, Tina Fey',
#   'rating': '8.06344821860451',
#   'vote': None,
#   'link': '/title/tt2948372/'},
#  {'movie_title': 'Mad Max: Fury Road',
#   'year': '2015',
#   'place': '207',
#   'star_cast': 'George Miller (dir.), Tom Hardy, Charlize Theron',
#   'rating': '8.061688269149073',
#   'vote': None,
#   'link': '/title/tt1392190/'},
#  {'movie_title': 'Million Dollar Baby',
#   'year': '2004',
#   'place': '208',
#   'star_cast': 'Clint Eastwood (dir.), Hilary Swank, Clint Eastwood',
#   'rating': '8.057601258464828',
#   'vote': None,
#   'link': '/title/tt0405159/'},
#  {'movie_title': 'Dead Poets Society',
#   'year': '1989',
#   'place': '209',
#   'star_cast': 'Peter Weir (dir.), Robin Williams, Robert Sean Leonard',
#   'rating': '8.057246957943521',
#   'vote': None,
#   'link': '/title/tt0097165/'},
#  {'movie_title': 'Network',
#   'year': '1976',
#   'place': '210',
#   'star_cast': 'Sidney Lumet (dir.), Faye Dunaway, William Holden',
#   'rating': '8.056296552571292',
#   'vote': None,
#   'link': '/title/tt0074958/'},
#  {'movie_title': 'Stand by Me',
#   'year': '1986',
#   'place': '211',
#   'star_cast': 'Rob Reiner (dir.), Wil Wheaton, River Phoenix',
#   'rating': '8.055700801305917',
#   'vote': None,
#   'link': '/title/tt0092005/'},
#  {'movie_title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'year': '2011',
#   'place': '212',
#   'star_cast': 'David Yates (dir.), Daniel Radcliffe, Emma Watson',
#   'rating': '8.05454696605945',
#   'vote': None,
#   'link': '/title/tt1201607/'},
#  {'movie_title': 'Ben-Hur',
#   'year': '1959',
#   'place': '213',
#   'star_cast': 'William Wyler (dir.), Charlton Heston, Jack Hawkins',
#   'rating': '8.053684420470343',
#   'vote': None,
#   'link': '/title/tt0052618/'},
#  {'movie_title': "Hachi: A Dog's Tale",
#   'year': '2009',
#   'place': '214',
#   'star_cast': 'Lasse Hallström (dir.), Richard Gere, Joan Allen',
#   'rating': '8.052457981346226',
#   'vote': None,
#   'link': '/title/tt1028532/'},
#  {'movie_title': 'Cool Hand Luke',
#   'year': '1967',
#   'place': '215',
#   'star_cast': 'Stuart Rosenberg (dir.), Paul Newman, George Kennedy',
#   'rating': '8.052338902675888',
#   'vote': None,
#   'link': '/title/tt0061512/'},
#  {'movie_title': 'Ah-ga-ssi',
#   'year': '2016',
#   'place': '216',
#   'star_cast': 'Chan-wook Park (dir.), Kim Min-hee, Jung-woo Ha',
#   'rating': '8.05000085649279',
#   'vote': None,
#   'link': '/title/tt4016934/'},
#  {'movie_title': 'Platoon',
#   'year': '1986',
#   'place': '217',
#   'star_cast': 'Oliver Stone (dir.), Charlie Sheen, Tom Berenger',
#   'rating': '8.049936888162128',
#   'vote': None,
#   'link': '/title/tt0091763/'},
#  {'movie_title': 'Logan',
#   'year': '2017',
#   'place': '218',
#   'star_cast': 'James Mangold (dir.), Hugh Jackman, Patrick Stewart',
#   'rating': '8.04964685282675',
#   'vote': None,
#   'link': '/title/tt3315342/'},
#  {'movie_title': 'Into the Wild',
#   'year': '2007',
#   'place': '219',
#   'star_cast': 'Sean Penn (dir.), Emile Hirsch, Vince Vaughn',
#   'rating': '8.048765336634371',
#   'vote': None,
#   'link': '/title/tt0758758/'},
#  {'movie_title': 'Le salaire de la peur',
#   'year': '1953',
#   'place': '220',
#   'star_cast': 'Henri-Georges Clouzot (dir.), Yves Montand, Charles Vanel',
#   'rating': '8.047781132262132',
#   'vote': None,
#   'link': '/title/tt0046268/'},
#  {'movie_title': 'Rush',
#   'year': '2013',
#   'place': '221',
#   'star_cast': 'Ron Howard (dir.), Daniel Brühl, Chris Hemsworth',
#   'rating': '8.047477830838341',
#   'vote': None,
#   'link': '/title/tt1979320/'},
#  {'movie_title': 'Life of Brian',
#   'year': '1979',
#   'place': '222',
#   'star_cast': 'Terry Jones (dir.), Graham Chapman, John Cleese',
#   'rating': '8.045627221601375',
#   'vote': None,
#   'link': '/title/tt0079470/'},
#  {'movie_title': 'La haine',
#   'year': '1995',
#   'place': '223',
#   'star_cast': 'Mathieu Kassovitz (dir.), Vincent Cassel, Hubert Koundé',
#   'rating': '8.043162146283233',
#   'vote': None,
#   'link': '/title/tt0113247/'},
#  {'movie_title': "La passion de Jeanne d'Arc",
#   'year': '1928',
#   'place': '224',
#   'star_cast': 'Carl Theodor Dreyer (dir.), Maria Falconetti, Eugene Silvain',
#   'rating': '8.042628165625981',
#   'vote': None,
#   'link': '/title/tt0019254/'},
#  {'movie_title': 'Les quatre cents coups',
#   'year': '1959',
#   'place': '225',
#   'star_cast': 'François Truffaut (dir.), Jean-Pierre Léaud, Albert Rémy',
#   'rating': '8.042574148884901',
#   'vote': None,
#   'link': '/title/tt0053198/'},
#  {'movie_title': 'Spotlight',
#   'year': '2015',
#   'place': '226',
#   'star_cast': 'Tom McCarthy (dir.), Mark Ruffalo, Michael Keaton',
#   'rating': '8.042554200756268',
#   'vote': None,
#   'link': '/title/tt1895587/'},
#  {'movie_title': 'Hotel Rwanda',
#   'year': '2004',
#   'place': '227',
#   'star_cast': 'Terry George (dir.), Don Cheadle, Sophie Okonedo',
#   'rating': '8.040897845786208',
#   'vote': None,
#   'link': '/title/tt0395169/'},
#  {'movie_title': 'Dom za vesanje',
#   'year': '1988',
#   'place': '228',
#   'star_cast': 'Emir Kusturica (dir.), Davor Dujmovic, Bora Todorovic',
#   'rating': '8.038412569597144',
#   'vote': None,
#   'link': '/title/tt0097223/'},
#  {'movie_title': 'Amores perros',
#   'year': '2000',
#   'place': '229',
#   'star_cast': 'Alejandro G. Iñárritu (dir.), Emilio Echevarría, Gael García Bernal',
#   'rating': '8.038117118176881',
#   'vote': None,
#   'link': '/title/tt0245712/'},
#  {'movie_title': 'Gangs of Wasseypur',
#   'year': '2012',
#   'place': '230',
#   'star_cast': 'Anurag Kashyap (dir.), Manoj Bajpayee, Richa Chadha',
#   'rating': '8.036529738312227',
#   'vote': None,
#   'link': '/title/tt1954470/'},
#  {'movie_title': 'Rocky',
#   'year': '1976',
#   'place': '231',
#   'star_cast': 'John G. Avildsen (dir.), Sylvester Stallone, Talia Shire',
#   'rating': '8.03529883806103',
#   'vote': None,
#   'link': '/title/tt0075148/'},
#  {'movie_title': 'Andrei Rublev',
#   'year': '1966',
#   'place': '232',
#   'star_cast': 'Andrei Tarkovsky (dir.), Anatoliy Solonitsyn, Ivan Lapikov',
#   'rating': '8.035288976356782',
#   'vote': None,
#   'link': '/title/tt0060107/'},
#  {'movie_title': 'Monsters, Inc',
#   'year': '2001',
#   'place': '233',
#   'star_cast': 'Pete Docter (dir.), Billy Crystal, John Goodman',
#   'rating': '8.034958226836949',
#   'vote': None,
#   'link': '/title/tt0198781/'},
#  {'movie_title': 'Kaze no tani no Naushika',
#   'year': '1984',
#   'place': '234',
#   'star_cast': 'Hayao Miyazaki (dir.), Sumi Shimamoto, Mahito Tsujimura',
#   'rating': '8.032897351252522',
#   'vote': None,
#   'link': '/title/tt0087544/'},
#  {'movie_title': 'Rebecca',
#   'year': '1940',
#   'place': '235',
#   'star_cast': 'Alfred Hitchcock (dir.), Laurence Olivier, Joan Fontaine',
#   'rating': '8.029841499642279',
#   'vote': None,
#   'link': '/title/tt0032976/'},
#  {'movie_title': 'Du rififi chez les hommes',
#   'year': '1955',
#   'place': '236',
#   'star_cast': 'Jules Dassin (dir.), Jean Servais, Carl Möhner',
#   'rating': '8.024760439651923',
#   'vote': None,
#   'link': '/title/tt0048021/'},
#  {'movie_title': 'Rang De Basanti',
#   'year': '2006',
#   'place': '237',
#   'star_cast': 'Rakeysh Omprakash Mehra (dir.), Aamir Khan, Soha Ali Khan',
#   'rating': '8.02449391576062',
#   'vote': None,
#   'link': '/title/tt0405508/'},
#  {'movie_title': 'Before Sunset',
#   'year': '2004',
#   'place': '238',
#   'star_cast': 'Richard Linklater (dir.), Ethan Hawke, Julie Delpy',
#   'rating': '8.023991525229137',
#   'vote': None,
#   'link': '/title/tt0381681/'},
#  {'movie_title': 'Fa yeung nin wah',
#   'year': '2000',
#   'place': '239',
#   'star_cast': 'Kar-Wai Wong (dir.), Tony Chiu-Wai Leung, Maggie Cheung',
#   'rating': '8.020878081464756',
#   'vote': None,
#   'link': '/title/tt0118694/'},
#  {'movie_title': 'Paris, Texas',
#   'year': '1984',
#   'place': '240',
#   'star_cast': 'Wim Wenders (dir.), Harry Dean Stanton, Nastassja Kinski',
#   'rating': '8.019114623335687',
#   'vote': None,
#   'link': '/title/tt0087884/'},
#  {'movie_title': 'Portrait de la jeune fille en feu',
#   'year': '2019',
#   'place': '241',
#   'star_cast': 'Céline Sciamma (dir.), Noémie Merlant, Adèle Haenel',
#   'rating': '8.015883107908293',
#   'vote': None,
#   'link': '/title/tt8613070/'},
#  {'movie_title': 'It Happened One Night',
#   'year': '1934',
#   'place': '242',
#   'star_cast': 'Frank Capra (dir.), Clark Gable, Claudette Colbert',
#   'rating': '8.015175298999843',
#   'vote': None,
#   'link': '/title/tt0025316/'},
#  {'movie_title': 'Contratiempo',
#   'year': '2016',
#   'place': '243',
#   'star_cast': 'Oriol Paulo (dir.), Mario Casas, Ana Wagener',
#   'rating': '8.01229150272888',
#   'vote': None,
#   'link': '/title/tt4857264/'},
#  {'movie_title': 'Drishyam',
#   'year': '2015',
#   'place': '244',
#   'star_cast': 'Nishikant Kamat (dir.), Ajay Devgn, Shriya Saran',
#   'rating': '8.012232032071722',
#   'vote': None,
#   'link': '/title/tt4430212/'},
#  {'movie_title': 'Koe no katachi',
#   'year': '2016',
#   'place': '245',
#   'star_cast': 'Naoko Yamada (dir.), Miyu Irino, Saori Hayami',
#   'rating': '8.011675554186997',
#   'vote': None,
#   'link': '/title/tt5323662/'},
#  {'movie_title': 'Mandariinid',
#   'year': '2013',
#   'place': '246',
#   'star_cast': 'Zaza Urushadze (dir.), Lembit Ulfsak, Elmo Nüganen',
#   'rating': '8.011581756319226',
#   'vote': None,
#   'link': '/title/tt2991224/'},
#  {'movie_title': 'The Help',
#   'year': '2011',
#   'place': '247',
#   'star_cast': 'Tate Taylor (dir.), Emma Stone, Viola Davis',
#   'rating': '8.011554805864955',
#   'vote': None,
#   'link': '/title/tt1454029/'},
#  {'movie_title': 'Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni',
#   'year': '1997',
#   'place': '248',
#   'star_cast': 'Hideaki Anno (dir.), Megumi Ogata, Megumi Hayashibara',
#   'rating': '8.011539761314385',
#   'vote': None,
#   'link': '/title/tt0169858/'},
#  {'movie_title': 'La battaglia di Algeri',
#   'year': '1966',
#   'place': '249',
#   'star_cast': 'Gillo Pontecorvo (dir.), Brahim Hadjadj, Jean Martin',
#   'rating': '8.011446699104166',
#   'vote': None,
#   'link': '/title/tt0058946/'},
#  {'movie_title': 'The Princess Bride',
#   'year': '1987',
#   'place': '250',
#   'star_cast': 'Rob Reiner (dir.), Cary Elwes, Mandy Patinkin',
#   'rating': '8.010628974218012',
#   'vote': None,
#   'link': '/title/tt0093779/'}]

# %%
import pandas as pd
rating= pd.DataFrame.from_dict(imdb[0:100])

# %%
rating
# Out:
#                  movie_title  year place  \
# 0   The Shawshank Redemption  1994     1
# 1              The Godfather  1972     2
# 2     The Godfather: Part II  1974     3
# 3            The Dark Knight  2008     4
# 4               12 Angry Men  1957     5
# ..                       ...   ...   ...
# 95              Citizen Kane  1941    96
# 96                    Dangal  2016    97
# 97         Full Metal Jacket  1987    98
# 98       Ladri di biciclette  1948    99
# 99       Singin' in the Rain  1952    10
#
#                                             star_cast             rating  \
# 0   Frank Darabont (dir.), Tim Robbins, Morgan Fre...   9.22338655927294
# 1   Francis Ford Coppola (dir.), Marlon Brando, Al...  9.148134749783218
# 2   Francis Ford Coppola (dir.), Al Pacino, Robert...   8.98035242665388
# 3   Christopher Nolan (dir.), Christian Bale, Heat...  8.974414613573318
# 4       Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb  8.933475530215347
# ..                                                ...                ...
# 95   Orson Welles (dir.), Orson Welles, Joseph Cotten   8.25531031684111
# 96    Nitesh Tiwari (dir.), Aamir Khan, Sakshi Tanwar  8.254360478174483
# 97  Stanley Kubrick (dir.), Matthew Modine, R. Lee...  8.246650646300221
# 98  Vittorio De Sica (dir.), Lamberto Maggiorani, ...  8.246560727648763
# 99  Stanley Donen (dir.), Gene Kelly, Donald O'Connor  8.246379406057104
#
#     vote               link
# 0   None  /title/tt0111161/
# 1   None  /title/tt0068646/
# 2   None  /title/tt0071562/
# 3   None  /title/tt0468569/
# 4   None  /title/tt0050083/
# ..   ...                ...
# 95  None  /title/tt0033467/
# 96  None  /title/tt5074352/
# 97  None  /title/tt0093058/
# 98  None  /title/tt0040522/
# 99  None  /title/tt0045152/
#
# [100 rows x 7 columns]

# %%
imdb_rating=rating.drop(['place','star_cast','vote','link'],axis=1)

# %%
imdb_rating
# Out:
#                  movie_title  year             rating
# 0   The Shawshank Redemption  1994   9.22338655927294
# 1              The Godfather  1972  9.148134749783218
# 2     The Godfather: Part II  1974   8.98035242665388
# 3            The Dark Knight  2008  8.974414613573318
# 4               12 Angry Men  1957  8.933475530215347
# ..                       ...   ...                ...
# 95              Citizen Kane  1941   8.25531031684111
# 96                    Dangal  2016  8.254360478174483
# 97         Full Metal Jacket  1987  8.246650646300221
# 98       Ladri di biciclette  1948  8.246560727648763
# 99       Singin' in the Rain  1952  8.246379406057104
#
# [100 rows x 3 columns]
